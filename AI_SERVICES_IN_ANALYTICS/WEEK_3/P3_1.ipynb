# %% [markdown]
# ![nyp.jpg](attachment:nyp.jpg)

# %% [markdown]
# # Google Cloud Natural Language API
#
# In this practical, we are going to learn more about the [Google Cloud Natural Language API](https://cloud.google.com/natural-language/docs).
#
# Cloud Natural Language allows us to perform the following operations:
# - [Analyse Syntax](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeSyntax)
# - [Analyse Entities](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeEntities)
# - [Analyse Sentiment](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeSentiment)
# - [Analyse Entity Sentiment](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeEntitySentiment)
# - [Classify Content](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/classifyText)
#
# Let's start with exploring [Cloud Natural Language Demo](https://cloud.google.com/natural-language/#natural-language-api-demo).

# %% [markdown]
# ### Todo
#
# > Try out the demo using your own text. Explore the Entities, Sentiment, Syntax and Categories tabs.

# %% [markdown]
# ## Using API Key
#
#
# We will now connect to the Cloud Natural Language API to perform multiple operations in a single request using the [annotateText](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/annotateText) method. Click on the link to find out the request format you need to fill in and what response you expect to get.

# %%
import requests
import json

# %% [markdown]
# These parameters are required to complete the request.

# %%
googleAPIKey = "AIzaSyBhNkvLI0d7ZcHxP95h7slBOs-5OT8nLa0"
googleurl = (
    "https://language.googleapis.com/v1/documents:annotateText?key=" + googleAPIKey
)
req_headers = {"Content-Type": "application/json"}

# %%
document = "Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects. They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education. Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries. Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study."

# %% [markdown]
# Make an API request. Ensure the request parameters are filled in correctly as required under [annotateText](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/annotateText#Features).

# %%
data = {
    "document": {"type": "PLAIN_TEXT", "content": document},
    "features": {
        "extractSyntax": True,
        "extractEntities": True,
        "extractDocumentSentiment": True,
        "extractEntitySentiment": True,
        "classifyText": True,
        "moderateText": True,
    },
    "encodingType": "UTF8",
}

r = requests.post(url=googleurl, headers=req_headers, json=data)

# Check and display the results
if r.status_code == 200:
    result = r.json()

    print(result)

    # loop through the response to get the parameters needed


else:
    print("Error with status")
    print(r.content)
# Out:
# {'sentences': [{'text': {'content': 'Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.', 'beginOffset': 0}, 'sentiment': {'magnitude': 0.9, 'score': 0.9}}, {'text': {'content': "They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education.", 'beginOffset': 171}, 'sentiment': {'magnitude': 0.8, 'score': 0.8}}, {'text': {'content': 'Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries.', 'beginOffset': 324}, 'sentiment': {'magnitude': 0.8, 'score': 0.8}}, {'text': {'content': 'Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study.', 'beginOffset': 460}, 'sentiment': {'magnitude': 0.8, 'score': 0.8}}], 'tokens': [{'text': {'content': 'Nanyang', 'beginOffset': 0}, 'partOfSpeech': {'tag': 'NOUN', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'SINGULAR', 'person': 'PERSON_UNKNOWN', 'proper': 'PROPER', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'TENSE_UNKNOWN', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 1, 'label': 'NN'}, 'lemma': 'Nanyang'}, {'text': {'content': 'Polytechnic', 'beginOffset': 8}, 'partOfSpeech': {'tag': 'NOUN', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'SINGULAR', 'person': 'PERSON_UNKNOWN', 'proper': 'PROPER', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'TENSE_UNKNOWN', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 2, 'label': 'NSUBJ'}, 'lemma': 'Polytechnic'}, {'text': {'content': 'gives', 'beginOffset': 20}, 'partOfSpeech': {'tag': 'VERB', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'INDICATIVE', 'number': 'SINGULAR', 'person': 'THIRD', 'proper': 'PROPER_UNKNOWN', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'PRESENT', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 2, 'label': 'ROOT'}, 'lemma': 'give'}, {'text': {'content': 'our', 'beginOffset': 26}, 'partOfSpeech': {'tag': 'PRON', 'aspect': 'ASPECT_UNKNOWN', 'case': 'GENITIVE', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'PLURAL', 'person': 'FIRST', 'proper': 'PROPER_UNKNOWN', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'TENSE_UNKNOWN', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 4, 'label': 'POSS'}, 'lemma': 'our'}, {'text': {'content': 'students', 'beginOffset': 30}, 'partOfSpeech': {'tag': 'NOUN', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'PLURAL', 'person': 'PERSON_UNKNOWN', 'proper': 'PROPER_UNKNOWN', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'TENSE_UNKNOWN', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 2, 'label': 'IOBJ'}, 'lemma': 'student'}, {'text': {'content': 'the', 'beginOffset': 39}, 'partOfSpeech': {'tag': 'DET', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'NUMBER_UNKNOWN', 'person': 'PERSON_UNKNOWN', 'proper': 'PROPER_UNKNOWN', 'reciprocity': 'RECIPROCITY_UNKNOWN', 'tense': 'TENSE_UNKNOWN', 'voice': 'VOICE_UNKNOWN'}, 'dependencyEdge': {'headTokenIndex': 7, 'label': 'DET'}, 'lemma': 'the'}, {'text': {'content': 'head', 'beginOffset': 43}, 'partOfSpeech': {'tag': 'NOUN', 'aspect': 'ASPECT_UNKNOWN', 'case': 'CASE_UNKNOWN', 'form': 'FORM_UNKNOWN', 'gender': 'GENDER_UNKNOWN', 'mood': 'MOOD_UNKNOWN', 'number': 'SINGULAR', 'person': 'PERSON_UNKNOWN', 'proper': 'PROPER_UNKNOWN', 'reciprocity': 'RECIPROCITY ...

# %%
# Pretty print JSON response
print(json.dumps(result, indent=4))
# Out:
# {
#     "sentences": [
#         {
#             "text": {
#                 "content": "Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.",
#                 "beginOffset": 0
#             },
#             "sentiment": {
#                 "magnitude": 0.9,
#                 "score": 0.9
#             }
#         },
#         {
#             "text": {
#                 "content": "They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education.",
#                 "beginOffset": 171
#             },
#             "sentiment": {
#                 "magnitude": 0.8,
#                 "score": 0.8
#             }
#         },
#         {
#             "text": {
#                 "content": "Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries.",
#                 "beginOffset": 324
#             },
#             "sentiment": {
#                 "magnitude": 0.8,
#                 "score": 0.8
#             }
#         },
#         {
#             "text": {
#                 "content": "Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study.",
#                 "beginOffset": 460
#             },
#             "sentiment": {
#                 "magnitude": 0.8,
#                 "score": 0.8
#             }
#         }
#     ],
#     "tokens": [
#         {
#             "text": {
#                 "content": "Nanyang",
#                 "beginOffset": 0
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 1,
#                 "label": "NN"
#             },
#             "lemma": "Nanyang"
#         },
#         {
#             "text": {
#                 "content": "Polytechnic",
#                 "beginOffset": 8
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 2,
#                 "label": "NSUBJ"
#             },
#             "lemma": "Polytechnic"
#         },
#         {
#             "text": {
#                 "content": "gives",
#                 "beginOffset": 20
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "INDICATIVE",
#                 "number": "SINGULAR",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PRESENT",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 2,
#                 "label": "ROOT"
#             },
#             "lemma": "give"
#         },
#         {
#             "text": {
#                 "content": "our",
#                 "beginOffset": 26
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "GENITIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "FIRST",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 4,
#                 "label": "POSS"
#             },
#             "lemma": "our"
#         },
#         {
#             "text": {
#                 "content": "students",
#                 "beginOffset": 30
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 2,
#                 "label": "IOBJ"
#             },
#             "lemma": "student"
#         },
#         {
#             "text": {
#                 "content": "the",
#                 "beginOffset": 39
#             },
#             "partOfSpeech": {
#                 "tag": "DET",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 7,
#                 "label": "DET"
#             },
#             "lemma": "the"
#         },
#         {
#             "text": {
#                 "content": "head",
#                 "beginOffset": 43
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 7,
#                 "label": "NN"
#             },
#             "lemma": "head"
#         },
#         {
#             "text": {
#                 "content": "start",
#                 "beginOffset": 48
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 2,
#                 "label": "DOBJ"
#             },
#             "lemma": "start"
#         },
#         {
#             "text": {
#                 "content": "they",
#                 "beginOffset": 54
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "NOMINATIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 10,
#                 "label": "NSUBJ"
#             },
#             "lemma": "they"
#         },
#         {
#             "text": {
#                 "content": "are",
#                 "beginOffset": 59
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "INDICATIVE",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PRESENT",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 10,
#                 "label": "AUX"
#             },
#             "lemma": "be"
#         },
#         {
#             "text": {
#                 "content": "looking",
#                 "beginOffset": 63
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PRESENT",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 7,
#                 "label": "RCMOD"
#             },
#             "lemma": "look"
#         },
#         {
#             "text": {
#                 "content": "for",
#                 "beginOffset": 71
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 10,
#                 "label": "PREP"
#             },
#             "lemma": "for"
#         },
#         {
#             "text": {
#                 "content": "in",
#                 "beginOffset": 75
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 10,
#                 "label": "PREP"
#             },
#             "lemma": "in"
#         },
#         {
#             "text": {
#                 "content": "their",
#                 "beginOffset": 78
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "GENITIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 15,
#                 "label": "POSS"
#             },
#             "lemma": "their"
#         },
#         {
#             "text": {
#                 "content": "next",
#                 "beginOffset": 84
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 15,
#                 "label": "AMOD"
#             },
#             "lemma": "next"
#         },
#         {
#             "text": {
#                 "content": "phase",
#                 "beginOffset": 89
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 12,
#                 "label": "POBJ"
#             },
#             "lemma": "phase"
#         },
#         {
#             "text": {
#                 "content": "in",
#                 "beginOffset": 95
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 15,
#                 "label": "PREP"
#             },
#             "lemma": "in"
#         },
#         {
#             "text": {
#                 "content": "life",
#                 "beginOffset": 98
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 16,
#                 "label": "POBJ"
#             },
#             "lemma": "life"
#         },
#         {
#             "text": {
#                 "content": "with",
#                 "beginOffset": 103
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 10,
#                 "label": "PREP"
#             },
#             "lemma": "with"
#         },
#         {
#             "text": {
#                 "content": "our",
#                 "beginOffset": 108
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "GENITIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "FIRST",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 22,
#                 "label": "POSS"
#             },
#             "lemma": "our"
#         },
#         {
#             "text": {
#                 "content": "innovative",
#                 "beginOffset": 112
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 22,
#                 "label": "AMOD"
#             },
#             "lemma": "innovative"
#         },
#         {
#             "text": {
#                 "content": "teaching",
#                 "beginOffset": 123
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 22,
#                 "label": "NN"
#             },
#             "lemma": "teaching"
#         },
#         {
#             "text": {
#                 "content": "methods",
#                 "beginOffset": 132
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 18,
#                 "label": "POBJ"
#             },
#             "lemma": "method"
#         },
#         {
#             "text": {
#                 "content": "and",
#                 "beginOffset": 140
#             },
#             "partOfSpeech": {
#                 "tag": "CONJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 22,
#                 "label": "CC"
#             },
#             "lemma": "and"
#         },
#         {
#             "text": {
#                 "content": "industry",
#                 "beginOffset": 144
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 26,
#                 "label": "NPADVMOD"
#             },
#             "lemma": "industry"
#         },
#         {
#             "text": {
#                 "content": "-",
#                 "beginOffset": 152
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 26,
#                 "label": "P"
#             },
#             "lemma": "-"
#         },
#         {
#             "text": {
#                 "content": "focused",
#                 "beginOffset": 153
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PAST",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 27,
#                 "label": "AMOD"
#             },
#             "lemma": "focuse"
#         },
#         {
#             "text": {
#                 "content": "projects",
#                 "beginOffset": 161
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 22,
#                 "label": "CONJ"
#             },
#             "lemma": "project"
#         },
#         {
#             "text": {
#                 "content": ".",
#                 "beginOffset": 169
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 2,
#                 "label": "P"
#             },
#             "lemma": "."
#         },
#         {
#             "text": {
#                 "content": "They",
#                 "beginOffset": 171
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "NOMINATIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 33,
#                 "label": "NSUBJ"
#             },
#             "lemma": "They"
#         },
#         {
#             "text": {
#                 "content": "'ll",
#                 "beginOffset": 175
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 33,
#                 "label": "AUX"
#             },
#             "lemma": "will"
#         },
#         {
#             "text": {
#                 "content": "not",
#                 "beginOffset": 179
#             },
#             "partOfSpeech": {
#                 "tag": "ADV",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 32,
#                 "label": "NEG"
#             },
#             "lemma": "not"
#         },
#         {
#             "text": {
#                 "content": "only",
#                 "beginOffset": 183
#             },
#             "partOfSpeech": {
#                 "tag": "ADV",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 33,
#                 "label": "PRECONJ"
#             },
#             "lemma": "only"
#         },
#         {
#             "text": {
#                 "content": "be",
#                 "beginOffset": 188
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 33,
#                 "label": "ROOT"
#             },
#             "lemma": "be"
#         },
#         {
#             "text": {
#                 "content": "academically",
#                 "beginOffset": 191
#             },
#             "partOfSpeech": {
#                 "tag": "ADV",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 35,
#                 "label": "ADVMOD"
#             },
#             "lemma": "academically"
#         },
#         {
#             "text": {
#                 "content": "prepared",
#                 "beginOffset": 204
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PAST",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 33,
#                 "label": "ACOMP"
#             },
#             "lemma": "prepared"
#         },
#         {
#             "text": {
#                 "content": ",",
#                 "beginOffset": 212
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 35,
#                 "label": "P"
#             },
#             "lemma": ","
#         },
#         {
#             "text": {
#                 "content": "but",
#                 "beginOffset": 214
#             },
#             "partOfSpeech": {
#                 "tag": "CONJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 38,
#                 "label": "CC"
#             },
#             "lemma": "but"
#         },
#         {
#             "text": {
#                 "content": "also",
#                 "beginOffset": 218
#             },
#             "partOfSpeech": {
#                 "tag": "ADV",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 35,
#                 "label": "CC"
#             },
#             "lemma": "also"
#         },
#         {
#             "text": {
#                 "content": "future",
#                 "beginOffset": 223
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 43,
#                 "label": "ADVMOD"
#             },
#             "lemma": "future"
#         },
#         {
#             "text": {
#                 "content": "-",
#                 "beginOffset": 229
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 43,
#                 "label": "P"
#             },
#             "lemma": "-"
#         },
#         {
#             "text": {
#                 "content": "ready",
#                 "beginOffset": 230
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 43,
#                 "label": "DEP"
#             },
#             "lemma": "ready"
#         },
#         {
#             "text": {
#                 "content": "-",
#                 "beginOffset": 236
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 43,
#                 "label": "P"
#             },
#             "lemma": "-"
#         },
#         {
#             "text": {
#                 "content": "equipped",
#                 "beginOffset": 238
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PAST",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 35,
#                 "label": "CONJ"
#             },
#             "lemma": "equip"
#         },
#         {
#             "text": {
#                 "content": "to",
#                 "beginOffset": 247
#             },
#             "partOfSpeech": {
#                 "tag": "PRT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 45,
#                 "label": "AUX"
#             },
#             "lemma": "to"
#         },
#         {
#             "text": {
#                 "content": "tackle",
#                 "beginOffset": 250
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 43,
#                 "label": "XCOMP"
#             },
#             "lemma": "tackle"
#         },
#         {
#             "text": {
#                 "content": "whatever",
#                 "beginOffset": 257
#             },
#             "partOfSpeech": {
#                 "tag": "DET",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 48,
#                 "label": "DOBJ"
#             },
#             "lemma": "whatever"
#         },
#         {
#             "text": {
#                 "content": "life",
#                 "beginOffset": 266
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 48,
#                 "label": "NSUBJ"
#             },
#             "lemma": "life"
#         },
#         {
#             "text": {
#                 "content": "throws",
#                 "beginOffset": 271
#             },
#             "partOfSpeech": {
#                 "tag": "VERB",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "INDICATIVE",
#                 "number": "SINGULAR",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "PRESENT",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 45,
#                 "label": "CCOMP"
#             },
#             "lemma": "throw"
#         },
#         {
#             "text": {
#                 "content": "at",
#                 "beginOffset": 278
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 48,
#                 "label": "PREP"
#             },
#             "lemma": "at"
#         },
#         {
#             "text": {
#                 "content": "them",
#                 "beginOffset": 281
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "ACCUSATIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 49,
#                 "label": "POBJ"
#             },
#             "lemma": "them"
#         },
#         {
#             "text": {
#                 "content": "in",
#                 "beginOffset": 286
#             },
#             "partOfSpeech": {
#                 "tag": "ADP",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 48,
#                 "label": "PREP"
#             },
#             "lemma": "in"
#         },
#         {
#             "text": {
#                 "content": "their",
#                 "beginOffset": 289
#             },
#             "partOfSpeech": {
#                 "tag": "PRON",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "GENITIVE",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "PLURAL",
#                 "person": "THIRD",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 53,
#                 "label": "POSS"
#             },
#             "lemma": "their"
#         },
#         {
#             "text": {
#                 "content": "career",
#                 "beginOffset": 295
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 51,
#                 "label": "POBJ"
#             },
#             "lemma": "career"
#         },
#         {
#             "text": {
#                 "content": "or",
#                 "beginOffset": 302
#             },
#             "partOfSpeech": {
#                 "tag": "CONJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 53,
#                 "label": "CC"
#             },
#             "lemma": "or"
#         },
#         {
#             "text": {
#                 "content": "further",
#                 "beginOffset": 305
#             },
#             "partOfSpeech": {
#                 "tag": "ADJ",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 56,
#                 "label": "AMOD"
#             },
#             "lemma": "far"
#         },
#         {
#             "text": {
#                 "content": "education",
#                 "beginOffset": 313
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
# ...
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 100,
#                 "label": "PREP"
#             },
#             "lemma": "of"
#         },
#         {
#             "text": {
#                 "content": "study",
#                 "beginOffset": 583
#             },
#             "partOfSpeech": {
#                 "tag": "NOUN",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "SINGULAR",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 101,
#                 "label": "POBJ"
#             },
#             "lemma": "study"
#         },
#         {
#             "text": {
#                 "content": ".",
#                 "beginOffset": 588
#             },
#             "partOfSpeech": {
#                 "tag": "PUNCT",
#                 "aspect": "ASPECT_UNKNOWN",
#                 "case": "CASE_UNKNOWN",
#                 "form": "FORM_UNKNOWN",
#                 "gender": "GENDER_UNKNOWN",
#                 "mood": "MOOD_UNKNOWN",
#                 "number": "NUMBER_UNKNOWN",
#                 "person": "PERSON_UNKNOWN",
#                 "proper": "PROPER_UNKNOWN",
#                 "reciprocity": "RECIPROCITY_UNKNOWN",
#                 "tense": "TENSE_UNKNOWN",
#                 "voice": "VOICE_UNKNOWN"
#             },
#             "dependencyEdge": {
#                 "headTokenIndex": 85,
#                 "label": "P"
#             },
#             "lemma": "."
#         }
#     ],
#     "entities": [
#         {
#             "name": "students",
#             "type": "PERSON",
#             "metadata": {},
#             "salience": 0.630127,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "students",
#                         "beginOffset": 30
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.6,
#                         "score": 0.6
#                     }
#                 },
#                 {
#                     "text": {
#                         "content": "students",
#                         "beginOffset": 377
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.4,
#                         "score": 0.4
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 2.4,
#                 "score": 0.4
#             }
#         },
#         {
#             "name": "Nanyang Polytechnic",
#             "type": "ORGANIZATION",
#             "metadata": {
#                 "mid": "/m/03x693",
#                 "wikipedia_url": "https://en.wikipedia.org/wiki/Nanyang_Polytechnic"
#             },
#             "salience": 0.07181117,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "Nanyang Polytechnic",
#                         "beginOffset": 0
#                     },
#                     "type": "PROPER",
#                     "sentiment": {
#                         "magnitude": 0.5,
#                         "score": 0.5
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.5,
#                 "score": 0.5
#             }
#         },
#         {
#             "name": "Many",
#             "type": "PERSON",
#             "metadata": {},
#             "salience": 0.058666345,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "Many",
#                         "beginOffset": 460
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 1,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "head start",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0565897,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "head start",
#                         "beginOffset": 43
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "life",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.032502554,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "life",
#                         "beginOffset": 98
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "phase",
#             "type": "EVENT",
#             "metadata": {},
#             "salience": 0.028625287,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "phase",
#                         "beginOffset": 89
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.5,
#                         "score": 0.5
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.5,
#                 "score": 0.5
#             }
#         },
#         {
#             "name": "teaching methods",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.028625287,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "teaching methods",
#                         "beginOffset": 123
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "projects",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.019429496,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "projects",
#                         "beginOffset": 161
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.5,
#                         "score": 0.5
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.5,
#                 "score": 0.5
#             }
#         },
#         {
#             "name": "universities",
#             "type": "ORGANIZATION",
#             "metadata": {},
#             "salience": 0.012969031,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "universities",
#                         "beginOffset": 522
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.6,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "life",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.011768444,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "life",
#                         "beginOffset": 266
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.1,
#                         "score": 0.1
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.1,
#                 "score": 0.1
#             }
#         },
#         {
#             "name": "career",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0087172575,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "career",
#                         "beginOffset": 295
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.2,
#                         "score": 0.2
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.2,
#                 "score": 0.2
#             }
#         },
#         {
#             "name": "education",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0087172575,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "education",
#                         "beginOffset": 313
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.2,
#                         "score": 0.2
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.2,
#                 "score": 0.2
#             }
#         },
#         {
#             "name": "graduates",
#             "type": "PERSON",
#             "metadata": {},
#             "salience": 0.0074204537,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "graduates",
#                         "beginOffset": 472
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "Graduate Employment Surveys",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0072182696,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "Graduate Employment Surveys",
#                         "beginOffset": 335
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "study",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0056995437,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "study",
#                         "beginOffset": 583
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "field",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.004568579,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "field",
#                         "beginOffset": 574
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.3,
#                         "score": 0.3
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.3,
#                 "score": 0.3
#             }
#         },
#         {
#             "name": "employers",
#             "type": "ORGANIZATION",
#             "metadata": {},
#             "salience": 0.0032721434,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "employers",
#                         "beginOffset": 426
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.2,
#                         "score": 0.2
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.2,
#                 "score": 0.2
#             }
#         },
#         {
#             "name": "industries",
#             "type": "OTHER",
#             "metadata": {},
#             "salience": 0.0032721434,
#             "mentions": [
#                 {
#                     "text": {
#                         "content": "industries",
#                         "beginOffset": 448
#                     },
#                     "type": "COMMON",
#                     "sentiment": {
#                         "magnitude": 0.2,
#                         "score": 0.2
#                     }
#                 }
#             ],
#             "sentiment": {
#                 "magnitude": 0.2,
#                 "score": 0.2
#             }
#         }
#     ],
#     "documentSentiment": {
#         "magnitude": 3.4,
#         "score": 0.8
#     },
#     "language": "en",
#     "categories": [
#         {
#             "name": "/Jobs & Education/Education/Colleges & Universities",
#             "confidence": 0.98
#         }
#     ],
#     "moderationCategories": [
#         {
#             "name": "Toxic",
#             "confidence": 0.014621646
#         },
#         {
#             "name": "Insult",
#             "confidence": 0.010393816
#         },
#         {
#             "name": "Profanity",
#             "confidence": 0.0029041197
#         },
#         {
#             "name": "Derogatory",
#             "confidence": 0.0035737436
#         },
#         {
#             "name": "Sexual",
#             "confidence": 0.0024352302
#         },
#         {
#             "name": "Death, Harm & Tragedy",
#             "confidence": 0.0051635113
#         },
#         {
#             "name": "Violent",
#             "confidence": 0
#         },
#         {
#             "name": "Firearms & Weapons",
#             "confidence": 0
#         },
#         {
#             "name": "Public Safety",
#             "confidence": 0.0014393667
#         },
#         {
#             "name": "Health",
#             "confidence": 0.03218884
#         },
#         {
#             "name": "Religion & Belief",
#             "confidence": 0.012507818
#         },
#         {
#             "name": "Illicit Drugs",
#             "confidence": 0.00955414
#         },
#         {
#             "name": "War & Conflict",
#             "confidence": 0.010416667
#         },
#         {
#             "name": "Politics",
#             "confidence": 0.0049586776
#         },
#         {
#             "name": "Finance",
#             "confidence": 0.01904762
#         },
#         {
#             "name": "Legal",
#             "confidence": 0.0029382957
#         }
#     ]
# }

# %%
print(result.keys())
# Out:
# dict_keys(['sentences', 'tokens', 'entities', 'documentSentiment', 'language', 'categories', 'moderationCategories'])

# %% [markdown]
# ### Analyse Syntax

# %% [markdown]
# Refer to [Analyse Syntax](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeSyntax). The expected response is shown below.
# ```
# {
#   "sentences": [
#     {
#       object (Sentence)
#     }
#   ],
#   "tokens": [
#     {
#       object (Token)
#     }
#   ],
#   "language": string
# }
#
# ```

# %% [markdown]
# **Sentences**

# %%
# keys are sentences, tokens and language
sentences = result["sentences"]

# %%
sentences
# Out:
# [{'text': {'content': 'Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.',
#    'beginOffset': 0},
#   'sentiment': {'magnitude': 0.9, 'score': 0.9}},
#  {'text': {'content': "They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education.",
#    'beginOffset': 171},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}},
#  {'text': {'content': 'Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries.',
#    'beginOffset': 324},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}},
#  {'text': {'content': 'Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study.',
#    'beginOffset': 460},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}}]

# %%
# explore first sentence
sentences[0]
# Out:
# {'text': {'content': 'Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.',
#   'beginOffset': 0},
#  'sentiment': {'magnitude': 0.9, 'score': 0.9}}

# %%
import pandas as pd

# %%
pd.set_option("display.max_colwidth", 0)

# %%
df1 = pd.concat(
    {
        "content": pd.Series([sentence["text"]["content"] for sentence in sentences]),
        "magnitude": pd.Series(
            [sentence["sentiment"]["magnitude"] for sentence in sentences]
        ),
        "score": pd.Series([sentence["sentiment"]["score"] for sentence in sentences]),
    },
    axis=1,
)

# %%
df1
# Out:
#                                                                                                                                                                       content  ...  score
# 0  Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.  ...  0.9
# 1  They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education.                    ...  0.8
# 2  Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries.                                     ...  0.8
# 3  Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study.                                           ...  0.8
#
# [4 rows x 3 columns]

# %% [markdown]
# **Tokens**

# %%
tokens = result["tokens"]

# %%
# explore first token
tokens[0]
# Out:
# {'text': {'content': 'Nanyang', 'beginOffset': 0},
#  'partOfSpeech': {'tag': 'NOUN',
#   'aspect': 'ASPECT_UNKNOWN',
#   'case': 'CASE_UNKNOWN',
#   'form': 'FORM_UNKNOWN',
#   'gender': 'GENDER_UNKNOWN',
#   'mood': 'MOOD_UNKNOWN',
#   'number': 'SINGULAR',
#   'person': 'PERSON_UNKNOWN',
#   'proper': 'PROPER',
#   'reciprocity': 'RECIPROCITY_UNKNOWN',
#   'tense': 'TENSE_UNKNOWN',
#   'voice': 'VOICE_UNKNOWN'},
#  'dependencyEdge': {'headTokenIndex': 1, 'label': 'NN'},
#  'lemma': 'Nanyang'}

# %%
tokens[0].keys()
# Out:
# dict_keys(['text', 'partOfSpeech', 'dependencyEdge', 'lemma'])

# %%
# create dataframe using partOfSpeech inside each token
df2 = pd.DataFrame([token["partOfSpeech"] for token in tokens])

# %%
df2
# Out:
#        tag  ...          voice
# 0    NOUN   ...  VOICE_UNKNOWN
# 1    NOUN   ...  VOICE_UNKNOWN
# 2    VERB   ...  VOICE_UNKNOWN
# 3    PRON   ...  VOICE_UNKNOWN
# 4    NOUN   ...  VOICE_UNKNOWN
# ..    ...   ...            ...
# 99   PRON   ...  VOICE_UNKNOWN
# 100  NOUN   ...  VOICE_UNKNOWN
# 101  ADP    ...  VOICE_UNKNOWN
# 102  NOUN   ...  VOICE_UNKNOWN
# 103  PUNCT  ...  VOICE_UNKNOWN
#
# [104 rows x 12 columns]

# %%
# create a pandas series using content inside each token
# then insert into first column of df2
df2.insert(0, "content", pd.Series([token["text"]["content"] for token in tokens]))
df2
# Out:
#          content  ...          voice
# 0    Nanyang      ...  VOICE_UNKNOWN
# 1    Polytechnic  ...  VOICE_UNKNOWN
# 2    gives        ...  VOICE_UNKNOWN
# 3    our          ...  VOICE_UNKNOWN
# 4    students     ...  VOICE_UNKNOWN
# ..        ...     ...            ...
# 99   their        ...  VOICE_UNKNOWN
# 100  field        ...  VOICE_UNKNOWN
# 101  of           ...  VOICE_UNKNOWN
# 102  study        ...  VOICE_UNKNOWN
# 103  .            ...  VOICE_UNKNOWN
#
# [104 rows x 13 columns]

# %%
# do the same for lemma
df2.insert(1, "lemma", pd.Series([token["lemma"] for token in tokens]))
df2
# Out:
#          content  ...          voice
# 0    Nanyang      ...  VOICE_UNKNOWN
# 1    Polytechnic  ...  VOICE_UNKNOWN
# 2    gives        ...  VOICE_UNKNOWN
# 3    our          ...  VOICE_UNKNOWN
# 4    students     ...  VOICE_UNKNOWN
# ..        ...     ...            ...
# 99   their        ...  VOICE_UNKNOWN
# 100  field        ...  VOICE_UNKNOWN
# 101  of           ...  VOICE_UNKNOWN
# 102  study        ...  VOICE_UNKNOWN
# 103  .            ...  VOICE_UNKNOWN
#
# [104 rows x 14 columns]

# %%
tokens[0]["dependencyEdge"]
# Out:
# {'headTokenIndex': 1, 'label': 'NN'}

# %%
# add columns for 'dependencyEdge': {'headTokenIndex': 1, 'label': 'NN'},
df2["d_edge_head_index"] = pd.Series(
    [token["dependencyEdge"]["headTokenIndex"] for token in tokens]
)
df2["d_edge_label"] = pd.Series([token["dependencyEdge"]["label"] for token in tokens])
df2
# Out:
#          content  ... d_edge_label
# 0    Nanyang      ...  NN
# 1    Polytechnic  ...  NSUBJ
# 2    gives        ...  ROOT
# 3    our          ...  POSS
# 4    students     ...  IOBJ
# ..        ...     ...   ...
# 99   their        ...  POSS
# 100  field        ...  POBJ
# 101  of           ...  PREP
# 102  study        ...  POBJ
# 103  .            ...  P
#
# [104 rows x 16 columns]

# %% [markdown]
# &#128161; **Tip:**
#
# > You can consolidate the commands in the previous cells and create a function `get_tokens_dataframe(tokens)` to simplify the process

# %% [markdown]
# Explore the different fields inside [Part of Speech](https://cloud.google.com/natural-language/docs/reference/rest/v1/Token#partofspeech).
#
# For example, [Person](https://cloud.google.com/natural-language/docs/reference/rest/v1/Token#Person) indicates different perspectives (i.e. FIRST, SECOND, etc.).

# %%
df2.loc[df2["person"] != "PERSON_UNKNOWN"]
# Out:
#    content  ... d_edge_label
# 2   gives   ...  ROOT
# 3   our     ...  POSS
# 8   they    ...  NSUBJ
# 13  their   ...  POSS
# 19  our     ...  POSS
# 29  They    ...  NSUBJ
# 48  throws  ...  CCOMP
# 50  them    ...  POBJ
# 52  their   ...  POSS
# 58  Our     ...  POSS
# 65  our     ...  POSS
# 81  our     ...  POSS
# 94  they    ...  NSUBJ
# 99  their   ...  POSS
#
# [14 rows x 16 columns]

# %% [markdown]
# What about [Number](https://cloud.google.com/natural-language/docs/reference/rest/v1/Token#number)? What does it represent?

# %%
df2["number"].value_counts()
# Out:
# number
# NUMBER_UNKNOWN    64
# SINGULAR          20
# PLURAL            20
# Name: count, dtype: int64

# %%
# which tokens are plural?
df2.loc[df2["number"] == "PLURAL"]
# Out:
#          content  ... d_edge_label
# 3   our           ...  POSS
# 4   students      ...  IOBJ
# 8   they          ...  NSUBJ
# 13  their         ...  POSS
# 19  our           ...  POSS
# 22  methods       ...  POBJ
# 27  projects      ...  CONJ
# 29  They          ...  NSUBJ
# 50  them          ...  POBJ
# 52  their         ...  POSS
# 58  Our           ...  POSS
# 65  our           ...  POSS
# 66  students      ...  NSUBJPASS
# 74  employers     ...  POBJ
# 77  industries    ...  POBJ
# 81  our           ...  POSS
# 82  graduates     ...  POBJ
# 91  universities  ...  POBJ
# 94  they          ...  NSUBJ
# 99  their         ...  POSS
#
# [20 rows x 16 columns]

# %%
# any token with known mood?
df2.loc[df2["mood"] != "MOOD_UNKNOWN"]
# Out:
#      content  ... d_edge_label
# 2   gives     ...  ROOT
# 9   are       ...  AUX
# 48  throws    ...  CCOMP
# 63  show      ...  ROOT
# 67  are       ...  AUXPASS
# 83  have      ...  AUX
# 95  continue  ...  RCMOD
#
# [7 rows x 16 columns]

# %% [markdown]
# Todo
#
# > Try processing different documents and see how the part of speech (e.g. gender, number, person, etc.) changes.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   content            104 non-null    object
#  1   lemma              104 non-null    object
#  2   tag                104 non-null    object
#  3   aspect             104 non-null    object
#  4   case               104 non-null    object
#  5   form               104 non-null    object
#  6   gender             104 non-null    object
#  7   mood               104 non-null    object
#  8   number             104 non-null    object
#  9   person             104 non-null    object
#  10  proper             104 non-null    object
#  11  reciprocity        104 non-null    object
#  12  tense              104 non-null    object
#  13  voice              104 non-null    object
#  14  d_edge_head_index  104 non-null    int64
#  15  d_edge_label       104 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 13.1+ KB

# %% [markdown]
# ### Analyse Entities

# %% [markdown]
# Refer to [Analyse Entities](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeEntities). The expected response is shown below.
# ```
# {
#   "entities": [
#     {
#       object (Entity)
#     }
#   ],
#   "language": string
# }
#
# ```

# %%
entities = result["entities"]
entities[0]
# Out:
# {'name': 'students',
#  'type': 'PERSON',
#  'metadata': {},
#  'salience': 0.630127,
#  'mentions': [{'text': {'content': 'students', 'beginOffset': 30},
#    'type': 'COMMON',
#    'sentiment': {'magnitude': 0.6, 'score': 0.6}},
#   {'text': {'content': 'students', 'beginOffset': 377},
#    'type': 'COMMON',
#    'sentiment': {'magnitude': 0.4, 'score': 0.4}}],
#  'sentiment': {'magnitude': 2.4, 'score': 0.4}}

# %%
df3 = pd.DataFrame(entities)
df3
# Out:
#                            name  ...                         sentiment
# 0   students                     ...  {'magnitude': 2.4, 'score': 0.4}
# 1   Nanyang Polytechnic          ...  {'magnitude': 0.5, 'score': 0.5}
# 2   Many                         ...  {'magnitude': 1, 'score': 0.3}
# 3   head start                   ...  {'magnitude': 0.3, 'score': 0.3}
# 4   life                         ...  {'magnitude': 0.3, 'score': 0.3}
# 5   phase                        ...  {'magnitude': 0.5, 'score': 0.5}
# 6   teaching methods             ...  {'magnitude': 0.3, 'score': 0.3}
# 7   projects                     ...  {'magnitude': 0.5, 'score': 0.5}
# 8   universities                 ...  {'magnitude': 0.6, 'score': 0.3}
# 9   life                         ...  {'magnitude': 0.1, 'score': 0.1}
# 10  career                       ...  {'magnitude': 0.2, 'score': 0.2}
# 11  education                    ...  {'magnitude': 0.2, 'score': 0.2}
# 12  graduates                    ...  {'magnitude': 0.3, 'score': 0.3}
# 13  Graduate Employment Surveys  ...  {'magnitude': 0.3, 'score': 0.3}
# 14  study                        ...  {'magnitude': 0.3, 'score': 0.3}
# 15  field                        ...  {'magnitude': 0.3, 'score': 0.3}
# 16  employers                    ...  {'magnitude': 0.2, 'score': 0.2}
# 17  industries                   ...  {'magnitude': 0.2, 'score': 0.2}
#
# [18 rows x 6 columns]

# %% [markdown]
# ### Analyse Sentiment

# %% [markdown]
# Refer to [Analyse Sentiment](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeSentiment). The expected response is shown below.
# ```
# {
#   "documentSentiment": {
#     object (Sentiment)
#   },
#   "language": string,
#   "sentences": [
#     {
#       object (Sentence)
#     }
#   ]
# }
# ```

# %%
result.keys()
# Out:
# dict_keys(['sentences', 'tokens', 'entities', 'documentSentiment', 'language', 'categories', 'moderationCategories'])

# %%
result["documentSentiment"]
# Out:
# {'magnitude': 3.4, 'score': 0.8}

# %%
result["sentences"]
# Out:
# [{'text': {'content': 'Nanyang Polytechnic gives our students the head start they are looking for in their next phase in life with our innovative teaching methods and industry-focused projects.',
#    'beginOffset': 0},
#   'sentiment': {'magnitude': 0.9, 'score': 0.9}},
#  {'text': {'content': "They'll not only be academically prepared, but also future-ready - equipped to tackle whatever life throws at them in their career or further education.",
#    'beginOffset': 171},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}},
#  {'text': {'content': 'Our annual Graduate Employment Surveys show that our students are consistently highly sought-after by employers in multiple industries.',
#    'beginOffset': 324},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}},
#  {'text': {'content': 'Many of our graduates have also gone on to local and overseas universities, where they continue to excel in their field of study.',
#    'beginOffset': 460},
#   'sentiment': {'magnitude': 0.8, 'score': 0.8}}]

# %% [markdown]
# ### Analyse Entity Sentiment

# %% [markdown]
# Refer to [Analyse Entity Sentiment](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeEntitySentiment). The expected response is shown below.
# ```
# {
#   "entities": [
#     {
#       object (Entity)
#     }
#   ],
#   "language": string
# }
# ```

# %% [markdown]
# Refer to Analyse Entity section on how to process entities.

# %% [markdown]
# ### Classify Content

# %% [markdown]
# Refer to [Classify Content](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/classifyText). The expected response is shown below.
#
# ```
# {
#   "categories": [
#     {
#       object (ClassificationCategory)
#     }
#   ]
# }
# ```

# %%
result["categories"]
# Out:
# [{'name': '/Jobs & Education/Education/Colleges & Universities',
#   'confidence': 0.98}]
