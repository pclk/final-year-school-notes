# %% [markdown]
# ![nyp.jpg](attachment:nyp.jpg)

# %% [markdown]
# # Client Library

# %% [markdown]
# Previously, we have been able to perform vision detections using just an API key. In this exercise, we will use the Cloud Client Library (Python) with a service key to perform Vision and Video predictions.
#
# Before we do that, we need to do some setup. Complete the following steps on your **PC/laptop**.

# %% [markdown]
# ### Set up PC
#
# 1. Download the [Google Cloud CLI installer](https://dl.google.com/dl/cloudsdk/channels/rapid/GoogleCloudSDKInstaller.exe)
# 2. Double click to install the SDK

# %% [markdown]
# 3. Click Next.

# %% [markdown]
# 4. Click "I Agree"
# 5. Use default installation path

# %% [markdown]
# 6. Click "Next" when done

# %% [markdown]
# 6. Check all the boxes and click "Finish"
# 7. The terminal window will auto launch gcloud init
# 8. Press Y

# %% [markdown]
# 9. Your browser will launch. Sign in to your personal Google account. Agree to the terms of service.
# 10. Once done, press the Win button, search for <code>Google Cloud SDK Shell</code> and launch it
# 11. Type <code>gcloud auth list</code> to see your active account; it should be the account you have just logged in
# 12. Type <code>gcloud config list</code> to see some info on configuration

# %% [markdown]
# ### Required files

# %% [markdown]
# Before you proceed, download the following data from Brightspace into the current directory:
# - <code>it3386-2024-s2.json</code>: service key
# - images from week 1 practical
# - <code>oh_2021_short.mp4</code>
#
# You should have also completed the Anaconda environment set up so that you can import the vison and video intelligence libraries. See the instructions on Brightspace.

# %% [markdown]
# Try performing a Vision Cloud Detection using the following codes.

# %%
print("hello")
# Out:
# hello

# %%
# %conda env list
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import vision
import io

# %%
# refer to https://cloud.google.com/vision/docs/detecting-faces

def detect_faces(path):
    """Detects faces in an image."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.face_detection(image=image)
    faces = response.face_annotations

    # Names of likelihood from google.cloud.vision.enums
    likelihood_name = ('UNKNOWN', 'VERY_UNLIKELY', 'UNLIKELY', 'POSSIBLE',
                       'LIKELY', 'VERY_LIKELY')
    print('Faces:')

    for face in faces:
        print('anger: {}'.format(likelihood_name[face.anger_likelihood]))
        print('joy: {}'.format(likelihood_name[face.joy_likelihood]))
        print('surprise: {}'.format(likelihood_name[face.surprise_likelihood]))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in face.bounding_poly.vertices])

        print('face bounds: {}'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(response.error.message))
    
    return response

# %%
# ensure the image is present in the current folder
response = detect_faces('nyp_cafe.jpg')
# Out:
# --------------------------------------------------
# DefaultCredentialsErrorTraceback (most recent call last)
# Cell In[3], line 2
#       1 # ensure the image is present in the current folder
# ----> 2 response = detect_faces('nyp_cafe.jpg')
#
# Cell In[2], line 7, in detect_faces(path)
#       5 from google.cloud import vision
#       6 import io
# ----> 7 client = vision.ImageAnnotatorClient()
#       9 with io.open(path, 'rb') as image_file:
#      10     content = image_file.read()
#
# File ~/miniconda3/lib/python3.12/site-packages/google/cloud/vision_v1/services/image_annotator/client.py:699, in ImageAnnotatorClient.__init__(self, credentials, transport, client_options, client_info)
#     691 transport_init: Union[
#     692     Type[ImageAnnotatorTransport], Callable[..., ImageAnnotatorTransport]
#     693 ] = (
#    (...)
#     696     else cast(Callable[..., ImageAnnotatorTransport], transport)
#     697 )
#     698 # initialize with the provided callable or the passed in class
# --> 699 self._transport = transport_init(
#     700     credentials=credentials,
#     701     credentials_file=self._client_options.credentials_file,
#     702     host=self._api_endpoint,
#     703     scopes=self._client_options.scopes,
#     704     client_cert_source_for_mtls=self._client_cert_source,
#     705     quota_project_id=self._client_options.quota_project_id,
#     706     client_info=client_info,
#     707     always_use_jwt_access=True,
#     708     api_audience=self._client_options.api_audience,
#     709 )
#
# File ~/miniconda3/lib/python3.12/site-packages/google/cloud/vision_v1/services/image_annotator/transports/grpc.py:157, in ImageAnnotatorGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     152             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     153                 certificate_chain=cert, private_key=key
#     154             )
#     156 # The base transport sets the host, credentials and scopes
# --> 157 super().__init__(
#     158     host=host,
#     159     credentials=credentials,
#     160     credentials_file=credentials_file,
#     161     scopes=scopes,
#     162     quota_project_id=quota_project_id,
#     163     client_info=client_info,
#     164     always_use_jwt_access=always_use_jwt_access,
#     165     api_audience=api_audience,
#     166 )
#     168 if not self._grpc_channel:
#     169     # initialize with the provided callable or the default channel
#     170     channel_init = channel or type(self).create_channel
#
# File ~/miniconda3/lib/python3.12/site-packages/google/cloud/vision_v1/services/image_annotator/transports/base.py:103, in ImageAnnotatorTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      99     credentials, _ = google.auth.load_credentials_from_file(
#     100         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#     101     )
#     102 elif credentials is None and not self._ignore_credentials:
# --> 103     credentials, _ = google.auth.default(
#     104         **scopes_kwargs, quota_project_id=quota_project_id
#     105     )
#     106     # Don't apply audience if the credentials file passed from user.
#     107     if hasattr(credentials, "with_gdch_audience"):
#
# File ~/miniconda3/lib/python3.12/site-packages/google/auth/_default.py:693, in default(scopes, request, quota_project_id, default_scopes)
#     685             _LOGGER.warning(
#     686                 "No project ID could be determined. Consider running "
#     687                 "`gcloud config set project` or setting the %s "
#     688                 "environment variable",
#     689                 environment_vars.PROJECT,
#     690             )
#     691         return credentials, effective_project_id
# --> 693 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %% [markdown]
# > Are you able to get a response from the detection? What is the error?

# %% [markdown]
# ### Set up environment
#
# The service key that you downloaded will give you the rights to complete the detections. Place them in the same directory.
#
# We will set up the GOOGLE_APPLICATION_CREDENTIALS env to link to the service key.

# %%
# you should see the service key (json) in your current folder
# !dir *.json

# %%
# env should be empty 
# %env GOOGLE_APPLICATION_CREDENTIALS

# %%
# set the service key
# %env GOOGLE_APPLICATION_CREDENTIALS=it3386-2024-s2.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=it3386-2024-s2.json

# %%
# %env GOOGLE_APPLICATION_CREDENTIALS
# Out:
# 'it3386-2024-s2.json'

# %% [markdown]
# ### Using Client Library for Vision

# %%
response = detect_faces('../WEEK_1/data/nyp_cafe.jpg')
# Out:
# Faces:
# anger: VERY_UNLIKELY
# joy: VERY_UNLIKELY
# surprise: VERY_UNLIKELY
# face bounds: (195,256),(244,256),(244,314),(195,314)
# anger: VERY_UNLIKELY
# joy: VERY_LIKELY
# surprise: VERY_UNLIKELY
# face bounds: (658,170),(752,170),(752,279),(658,279)
# anger: VERY_UNLIKELY
# joy: LIKELY
# surprise: VERY_UNLIKELY
# face bounds: (458,87),(560,87),(560,205),(458,205)

# %%
print(response)
# Out:
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 256
#     }
#     vertices {
#       x: 244
#       y: 256
#     }
#     vertices {
#       x: 244
#       y: 314
#     }
#     vertices {
#       x: 195
#       y: 314
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 198
#       y: 265
#     }
#     vertices {
#       x: 243
#       y: 265
#     }
#     vertices {
#       x: 243
#       y: 311
#     }
#     vertices {
#       x: 198
#       y: 311
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE
#     position {
#       x: 232.8819122314453
#       y: 285.9496154785156
#       z: -0.0016236305236816406
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE
#     position {
#       x: 221.1948699951172
#       y: 284.4725341796875
#       z: 8.73569393157959
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 234.22482299804688
#       y: 280.69549560546875
#       z: -4.279675483703613
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 233.62600708007812
#       y: 281.9647216796875
#       z: 3.7473411560058594
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 222.35096740722656
#       y: 280.822998046875
#       z: 9.179739952087402
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 219.16700744628906
#       y: 281.6358337402344
#       z: 10.311086654663086
#     }
#   }
#   landmarks {
#     type_: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 229.76028442382812
#       y: 285.4924621582031
#       z: 6.564626693725586
#     }
#   }
#   landmarks {
#     type_: NOSE_TIP
#     position {
#       x: 232.9110870361328
#       y: 293.8139343261719
#       z: 10.304009437561035
#     }
#   }
#   landmarks {
#     type_: UPPER_LIP
#     position {
#       x: 229.38717651367188
#       y: 298.35125732421875
#       z: 8.055306434631348
#     }
#   }
#   landmarks {
#     type_: LOWER_LIP
#     position {
#       x: 230.04078674316406
#       y: 302.8259582519531
#       z: 7.3422980308532715
#     }
#   }
#   landmarks {
#     type_: MOUTH_LEFT
#     position {
#       x: 231.2681121826172
#       y: 299.4408874511719
#       z: 1.4354579448699951
#     }
#   }
#   landmarks {
#     type_: MOUTH_RIGHT
#     position {
#       x: 222.8512420654297
#       y: 300.11083984375
#       z: 8.664429664611816
#     }
#   }
#   landmarks {
#     type_: MOUTH_CENTER
#     position {
#       x: 229.58102416992188
#       y: 300.2936706542969
#       z: 7.216250896453857
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_RIGHT
#     position {
#       x: 229.2864532470703
#       y: 293.9316101074219
#       z: 7.8629608154296875
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_LEFT
#     position {
#       x: 228.03482055664062
#       y: 293.66705322265625
#       z: 4.141024589538574
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_CENTER
#     position {
#       x: 229.40713500976562
#       y: 295.6044006347656
#       z: 8.000714302062988
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 232.9768829345703
#       y: 284.0024719238281
#       z: 0.5002442598342896
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 232.15318298339844
#       y: 285.6467590332031
#       z: 1.495978832244873
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 232.9730682373047
#       y: 287.1070251464844
#       z: 0.0019825100898742676
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 231.48239135742188
#       y: 285.9557800292969
#       z: -2.3621506690979004
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 221.53260803222656
#       y: 283.1046142578125
#       z: 9.399073600769043
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 220.5285186767578
#       y: 284.74627685546875
#       z: 9.021549224853516
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 221.60653686523438
#       y: 285.8799743652344
#       z: 8.964568138122559
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 222.84902954101562
#       y: 284.87725830078125
#       z: 7.048344612121582
#     }
#   }
#   landmarks {
#     type_: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 235.0201873779297
#       y: 279.63165283203125
#       z: 0.3668396472930908
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 221.6864013671875
#       y: 279.4936828613281
#       z: 10.125781059265137
#     }
#   }
#   landmarks {
#     type_: LEFT_EAR_TRAGION
#     position {
#       x: 235.52081298828125
#       y: 290.96417236328125
#       z: -19.663137435913086
#     }
#   }
#   landmarks {
#     type_: RIGHT_EAR_TRAGION
#     position {
#       x: 199.4480438232422
#       y: 288.68487548828125
#       z: 0.6755526065826416
#     }
#   }
#   landmarks {
#     type_: FOREHEAD_GLABELLA
#     position {
#       x: 230.0005645751953
#       y: 280.9144592285156
#       z: 6.518265724182129
#     }
#   }
#   landmarks {
#     type_: CHIN_GNATHION
#     position {
#       x: 230.24703979492188
#       y: 309.8444519042969
#       z: 5.988308429718018
#     }
#   }
#   landmarks {
#     type_: CHIN_LEFT_GONION
#     position {
#       x: 234.42686462402344
#       y: 303.3885498046875
#       z: -11.810009956359863
#     }
#   }
#   landmarks {
#     type_: CHIN_RIGHT_GONION
#     position {
#       x: 210.1693115234375
#       y: 301.8008728027344
#       z: 3.9180643558502197
#     }
#   }
#   landmarks {
#     type_: LEFT_CHEEK_CENTER
#     position {
#       x: 231.53651428222656
#       y: 294.4880065917969
#       z: -1.9200589656829834
#     }
#   }
#   landmarks {
#     type_: RIGHT_CHEEK_CENTER
#     position {
#       x: 220.24838256835938
#       y: 293.7214050292969
#       z: 9.355595588684082
#     }
#   }
#   roll_angle: 1.2892885208129883
#   pan_angle: 143.31556701660156
#   tilt_angle: -2.2655537128448486
#   detection_confidence: 0.72265625
#   landmarking_confidence: 0.0033869389444589615
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_UNLIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 658
#       y: 170
#     }
#     vertices {
#       x: 752
#       y: 170
#     }
#     vertices {
#       x: 752
#       y: 279
#     }
#     vertices {
#       x: 658
#       y: 279
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 669
#       y: 191
#     }
#     vertices {
#       x: 747
#       y: 191
#     }
#     vertices {
#       x: 747
#       y: 268
#     }
#     vertices {
#       x: 669
#       y: 268
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE
#     position {
#       x: 681.0192260742188
#       y: 220.03067016601562
#       z: 0.000614464282989502
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE
#     position {
#       x: 704.5885009765625
#       y: 216.91883850097656
#       z: -10.878156661987305
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 672.1260375976562
#       y: 215.55145263671875
#       z: 6.939079761505127
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 686.0027465820312
#       y: 212.5896759033203
#       z: -6.725699424743652
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 696.4365234375
#       y: 211.31643676757812
#       z: -11.814050674438477
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 714.6358032226562
#       y: 210.09475708007812
#       z: -11.742155075073242
#     }
#   }
#   landmarks {
#     type_: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 691.6289672851562
#       y: 217.597900390625
#       z: -10.505730628967285
#     }
#   }
#   landmarks {
#     type_: NOSE_TIP
#     position {
#       x: 686.9822387695312
#       y: 234.36883544921875
#       z: -20.212406158447266
#     }
#   }
#   landmarks {
#     type_: UPPER_LIP
#     position {
#       x: 691.67626953125
#       y: 241.9410400390625
#       z: -15.889594078063965
#     }
#   }
#   landmarks {
#     type_: LOWER_LIP
#     position {
#       x: 693.1621704101562
#       y: 253.11276245117188
#       z: -15.894864082336426
#     }
#   }
#   landmarks {
#     type_: MOUTH_LEFT
#     position {
#       x: 686.9166870117188
#       y: 249.12611389160156
#       z: -6.309155464172363
#     }
#   }
#   landmarks {
#     type_: MOUTH_RIGHT
#     position {
#       x: 708.1062622070312
#       y: 244.59698486328125
#       z: -14.84142780303955
#     }
#   }
#   landmarks {
#     type_: MOUTH_CENTER
#     position {
#       x: 692.565673828125
#       y: 247.76724243164062
#       z: -14.934416770935059
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_RIGHT
#     position {
#       x: 699.3156127929688
#       y: 234.15760803222656
#       z: -14.2781400680542
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_LEFT
#     position {
#       x: 685.7576904296875
#       y: 235.91912841796875
#       z: -8.126646995544434
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_CENTER
#     position {
#       x: 691.0127563476562
#       y: 237.3990478515625
#       z: -15.249773025512695
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 680.0306396484375
#       y: 217.36537170410156
#       z: -0.8451839685440063
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 685.9010009765625
#       y: 219.8137969970703
#       z: -2.33156418800354
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 680.6019897460938
#       y: 222.4279022216797
#       z: -0.5081601738929749
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 675.20458984375
#       y: 220.8329315185547
#       z: 4.740306854248047
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 704.3659057617188
#       y: 214.11672973632812
#       z: -12.07594108581543
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 711.3848876953125
#       y: 216.6287384033203
#       z: -11.185022354125977
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 705.0068969726562
#       y: 219.11485290527344
#       z: -11.666499137878418
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 700.3104858398438
#       y: 217.62643432617188
#       z: -8.79569149017334
#     }
#   }
#   landmarks {
#     type_: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 679.00927734375
#       y: 211.64859008789062
#       z: -1.1347737312316895
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 704.3368530273438
#       y: 208.16688537597656
#       z: -12.866317749023438
#     }
#   }
#   landmarks {
#     type_: LEFT_EAR_TRAGION
#     position {
#       x: 676.0772705078125
#       y: 237.4713897705078
#       z: 35.20545196533203
#     }
#   }
#   landmarks {
#     type_: RIGHT_EAR_TRAGION
#     position {
#       x: 741.8470458984375
#       y: 230.51751708984375
#       z: 9.316326141357422
#     }
#   }
#   landmarks {
#     type_: FOREHEAD_GLABELLA
#     position {
#       x: 690.9303588867188
#       y: 211.6235809326172
#       z: -10.032445907592773
#     }
#   }
#   landmarks {
#     type_: CHIN_GNATHION
#     position {
#       x: 696.7999877929688
#       y: 266.6658020019531
#       z: -14.695919036865234
#     }
#   }
#   landmarks {
#     type_: CHIN_LEFT_GONION
#     position {
#       x: 682.3295288085938
#       y: 256.34564208984375
#       z: 19.617515563964844
#     }
#   }
#   landmarks {
#     type_: CHIN_RIGHT_GONION
#     position {
#       x: 730.190185546875
#       y: 251.0467529296875
#       z: -0.9052724838256836
#     }
#   }
#   landmarks {
#     type_: LEFT_CHEEK_CENTER
#     position {
#       x: 677.3566284179688
#       y: 238.6951904296875
#       z: 1.62147057056427
#     }
#   }
#   landmarks {
#     type_: RIGHT_CHEEK_CENTER
#     position {
#       x: 712.6577758789062
#       y: 233.97311401367188
#       z: -13.678478240966797
#     }
#   }
#   roll_angle: -4.109051704406738
#   pan_angle: -24.005722045898438
#   tilt_angle: 8.093060493469238
#   detection_confidence: 0.98828125
#   landmarking_confidence: 0.4183005392551422
#   joy_likelihood: VERY_LIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_UNLIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 458
#       y: 87
#     }
#     vertices {
#       x: 560
#       y: 87
#     }
#     vertices {
#       x: 560
#       y: 205
#     }
#     vertices {
#       x: 458
#       y: 205
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 465
#       y: 115
#     }
#     vertices {
#       x: 544
#       y: 115
#     }
#     vertices {
#       x: 544
#       y: 195
#     }
#     vertices {
#       x: 465
#       y: 195
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE
#     position {
#       x: 522.409912109375
#       y: 144.51173400878906
#       z: -0.0010862350463867188
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE
#     position {
#       x: 539.0193481445312
#       y: 145.67762756347656
#       z: 25.603044509887695
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 514.8139038085938
#       y: 135.46563720703125
#       z: -7.362827301025391
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 533.503173828125
#       y: 136.96754455566406
#       z: 3.471879005432129
#     }
#   }
#   landmarks {
#     type_: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 539.5648193359375
#       y: 137.3686065673828
#       z: 15.26107406616211
#     }
#   }
#   landmarks {
#     type_: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 546.8145141601562
#       y: 140.69204711914062
#       z: 36.50212097167969
#     }
#   }
#   landmarks {
#     type_: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 535.572021484375
#       y: 143.14630126953125
#       z: 8.993255615234375
#     }
#   }
#   landmarks {
#     type_: NOSE_TIP
#     position {
#       x: 541.0592651367188
#       y: 165.68234252929688
#       z: 3.4810266494750977
#     }
#   }
#   landmarks {
#     type_: UPPER_LIP
#     position {
#       x: 534.3281860351562
#       y: 175.1138458251953
#       z: 7.755796432495117
#     }
#   }
#   landmarks {
#     type_: LOWER_LIP
#     position {
#       x: 529.1419677734375
#       y: 185.76998901367188
#       z: 8.765483856201172
#     }
#   }
#   landmarks {
#     type_: MOUTH_LEFT
#     position {
#       x: 517.921630859375
#       y: 175.7083740234375
#       z: 1.2765288352966309
#     }
#   }
#   landmarks {
#     type_: MOUTH_RIGHT
#     position {
#       x: 532.6293334960938
#       y: 180.4371795654297
#       z: 22.681730270385742
#     }
#   }
#   landmarks {
#     type_: MOUTH_CENTER
#     position {
#       x: 530.2864379882812
#       y: 180.16720581054688
#       z: 8.886263847351074
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_RIGHT
#     position {
#       x: 537.7229614257812
#       y: 167.44972229003906
#       z: 17.76376724243164
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_LEFT
#     position {
#       x: 527.9857788085938
#       y: 165.97314453125
#       z: 3.3612663745880127
#     }
#   }
#   landmarks {
#     type_: NOSE_BOTTOM_CENTER
#     position {
#       x: 535.3643188476562
#       y: 169.5454559326172
#       z: 7.71861457824707
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 523.2094116210938
#       y: 141.90196228027344
#       z: -1.4990386962890625
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 525.797607421875
#       y: 144.9540252685547
#       z: 5.246354103088379
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 521.8065795898438
#       y: 147.19796752929688
#       z: -0.7061762809753418
#     }
#   }
#   landmarks {
#     type_: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 516.8067626953125
#       y: 143.86376953125
#       z: -3.7607078552246094
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 541.4896850585938
#       y: 143.99176025390625
#       z: 24.958209991455078
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 543.9202880859375
#       y: 147.31689453125
#       z: 33.578548431396484
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 539.9608764648438
#       y: 148.54974365234375
#       z: 25.85611343383789
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 535.478271484375
#       y: 145.0357208251953
#       z: 20.307451248168945
#     }
#   }
#   landmarks {
#     type_: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 525.9911499023438
#       y: 133.4818115234375
#       z: -3.0568323135375977
#     }
#   }
#   landmarks {
#     type_: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 541.8805541992188
#       y: 136.41368103027344
#       z: 24.056041717529297
#     }
#   }
#   landmarks {
#     type_: LEFT_EAR_TRAGION
#     position {
#       x: 479.53741455078125
#       y: 154.72879028320312
#       z: 6.23862361907959
#     }
#   }
#   landmarks {
#     type_: RIGHT_EAR_TRAGION
#     position {
#       x: 525.0584716796875
#       y: 154.43324279785156
#       z: 66.00053405761719
#     }
#   }
#   landmarks {
#     type_: FOREHEAD_GLABELLA
#     position {
#       x: 536.630859375
#       y: 136.44696044921875
#       z: 8.629546165466309
#     }
#   }
#   landmarks {
#     type_: CHIN_GNATHION
#     position {
#       x: 522.370361328125
#       y: 198.62033081054688
#       z: 11.28657341003418
#     }
#   }
#   landmarks {
#     type_: CHIN_LEFT_GONION
#     position {
#       x: 487.62774658203125
#       y: 177.353271484375
#       z: 3.683781147003174
#     }
#   }
#   landmarks {
#     type_: CHIN_RIGHT_GONION
#     position {
#       x: 518.6766357421875
#       y: 184.62774658203125
#       z: 52.00882339477539
#     }
#   }
#   landmarks {
#     type_: LEFT_CHEEK_CENTER
#     position {
#       x: 513.6790161132812
#       y: 164.59519958496094
#       z: -3.55703067779541
#     }
#   }
#   landmarks {
#     type_: RIGHT_CHEEK_CENTER
#     position {
#       x: 539.7821044921875
#       y: 168.77633666992188
#       z: 32.73594284057617
#     }
#   }
#   roll_angle: 7.863421440124512
#   pan_angle: 53.830482482910156
#   tilt_angle: -0.3720502555370331
#   detection_confidence: 0.98046875
#   landmarking_confidence: 0.19363102316856384
#   joy_likelihood: LIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_UNLIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }

# %%
def detect_landmarks(path):
    """Detects landmarks in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.landmark_detection(image=image)
    landmarks = response.landmark_annotations
    print('Landmarks:')

    for landmark in landmarks:
        print(landmark.description)
        for location in landmark.locations:
            lat_lng = location.lat_lng
            print('Latitude {}'.format(lat_lng.latitude))
            print('Longitude {}'.format(lat_lng.longitude))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(response.error.message))
        
    return response

# %%
response = detect_landmarks('../WEEK_1/data/place.jpg')
# Out:
# Landmarks:
# Merlion Park
# Latitude 1.2867449000000002
# Longitude 103.8543872
# Artscience Museum
# Latitude 1.2862738
# Longitude 103.8592663
# Jubilee Bridge
# Latitude 1.2879361000000003
# Longitude 103.8543861
# Esplanade - Theatres On The Bay, Singapore
# Latitude 1.2897934
# Longitude 103.8558166

# %%
print(response)
# Out:
# landmark_annotations {
#   mid: "/g/11bwmwgb2l"
#   description: "Merlion Park"
#   score: 0.6081422567367554
#   bounding_poly {
#     vertices {
#     }
#     vertices {
#       x: 800
#     }
#     vertices {
#       x: 800
#       y: 800
#     }
#     vertices {
#       y: 800
#     }
#   }
#   locations {
#     lat_lng {
#       latitude: 1.2867449000000002
#       longitude: 103.8543872
#     }
#   }
# }
# landmark_annotations {
#   mid: "/m/0gff2yr"
#   description: "Artscience Museum"
#   score: 0.5705945491790771
#   bounding_poly {
#     vertices {
#     }
#     vertices {
#       x: 800
#     }
#     vertices {
#       x: 800
#       y: 800
#     }
#     vertices {
#       y: 800
#     }
#   }
#   locations {
#     lat_lng {
#       latitude: 1.2862738
#       longitude: 103.8592663
#     }
#   }
# }
# landmark_annotations {
#   mid: "/g/11fkf0scbc"
#   description: "Jubilee Bridge"
#   score: 0.5641544461250305
#   bounding_poly {
#     vertices {
#     }
#     vertices {
#       x: 800
#     }
#     vertices {
#       x: 800
#       y: 800
#     }
#     vertices {
#       y: 800
#     }
#   }
#   locations {
#     lat_lng {
#       latitude: 1.2879361000000003
#       longitude: 103.8543861
#     }
#   }
# }
# landmark_annotations {
#   mid: "/m/05kkqm"
#   description: "Esplanade - Theatres On The Bay, Singapore"
#   score: 0.5611713528633118
#   bounding_poly {
#     vertices {
#     }
#     vertices {
#       x: 800
#     }
#     vertices {
#       x: 800
#       y: 800
#     }
#     vertices {
#       y: 800
#     }
#   }
#   locations {
#     lat_lng {
#       latitude: 1.2897934
#       longitude: 103.8558166
#     }
#   }
# }

# %%
def detect_document(path):
    """Detects document features in an image."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.document_text_detection(image=image)

    for page in response.full_text_annotation.pages:
        for block in page.blocks:
            print('\nBlock confidence: {}\n'.format(block.confidence))

            for paragraph in block.paragraphs:
                print('Paragraph confidence: {}'.format(
                    paragraph.confidence))

                for word in paragraph.words:
                    word_text = ''.join([
                        symbol.text for symbol in word.symbols
                    ])
                    print('Word text: {} (confidence: {})'.format(
                        word_text, word.confidence))

                    for symbol in word.symbols:
                        print('\tSymbol: {} (confidence: {})'.format(
                            symbol.text, symbol.confidence))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(response.error.message))
    
    return response

# %%
response = detect_document('../WEEK_1/data/note.jpg')
# Out:
# Block confidence: 0.9424569010734558
#
# Paragraph confidence: 0.9424569010734558
# Word text: # (confidence: 0.8970488905906677)
# 	Symbol: # (confidence: 0.8970488905906677)
# Word text: 1 (confidence: 0.9878649115562439)
# 	Symbol: 1 (confidence: 0.9878649115562439)
#
# Block confidence: 0.9475244283676147
#
# Paragraph confidence: 0.9475244283676147
# Word text: What (confidence: 0.945880651473999)
# 	Symbol: W (confidence: 0.8481331467628479)
# 	Symbol: h (confidence: 0.9859771728515625)
# 	Symbol: a (confidence: 0.9818291664123535)
# 	Symbol: t (confidence: 0.9675832390785217)
# Word text: is (confidence: 0.956630289554596)
# 	Symbol: i (confidence: 0.95005202293396)
# 	Symbol: s (confidence: 0.9632085561752319)
# Word text: Mindfulness (confidence: 0.9464665055274963)
# 	Symbol: M (confidence: 0.6991844177246094)
# 	Symbol: i (confidence: 0.9543477296829224)
# 	Symbol: n (confidence: 0.9411085247993469)
# 	Symbol: d (confidence: 0.9776654243469238)
# 	Symbol: f (confidence: 0.9693295955657959)
# 	Symbol: u (confidence: 0.9358998537063599)
# 	Symbol: l (confidence: 0.985048770904541)
# 	Symbol: n (confidence: 0.9792196750640869)
# 	Symbol: e (confidence: 0.9965243935585022)
# 	Symbol: s (confidence: 0.9913613200187683)
# 	Symbol: s (confidence: 0.9814419150352478)
#
# Block confidence: 0.8348113298416138
#
# Paragraph confidence: 0.8348113298416138
# Word text: # (confidence: 0.7083378434181213)
# 	Symbol: # (confidence: 0.7083378434181213)
# Word text: 2 (confidence: 0.961284875869751)
# 	Symbol: 2 (confidence: 0.961284875869751)
#
# Block confidence: 0.9432740211486816
#
# Paragraph confidence: 0.9432740211486816
# Word text: Habits (confidence: 0.9827144145965576)
# 	Symbol: H (confidence: 0.9608584046363831)
# 	Symbol: a (confidence: 0.9833772778511047)
# 	Symbol: b (confidence: 0.9801293015480042)
# 	Symbol: i (confidence: 0.9958483576774597)
# 	Symbol: t (confidence: 0.9907765984535217)
# 	Symbol: s (confidence: 0.9852966070175171)
# Word text: of (confidence: 0.9578967094421387)
# 	Symbol: o (confidence: 0.9455196857452393)
# 	Symbol: f (confidence: 0.9702737927436829)
# Word text: Mind (confidence: 0.8768020272254944)
# 	Symbol: M (confidence: 0.9587565660476685)
# 	Symbol: i (confidence: 0.9635127782821655)
# 	Symbol: n (confidence: 0.6933403015136719)
# 	Symbol: d (confidence: 0.8915984630584717)
#
# Block confidence: 0.7889934778213501
#
# Paragraph confidence: 0.7889934778213501
# Word text: # (confidence: 0.6056626439094543)
# 	Symbol: # (confidence: 0.6056626439094543)
# Word text: 3 (confidence: 0.9723243713378906)
# 	Symbol: 3 (confidence: 0.9723243713378906)
#
# Block confidence: 0.9205087423324585
#
# Paragraph confidence: 0.9205087423324585
# Word text: Understanding (confidence: 0.9463872313499451)
# 	Symbol: U (confidence: 0.6658496856689453)
# 	Symbol: n (confidence: 0.9127954244613647)
# 	Symbol: d (confidence: 0.9470639824867249)
# 	Symbol: e (confidence: 0.9861584901809692)
# 	Symbol: r (confidence: 0.9170764684677124)
# 	Symbol: s (confidence: 0.9776014685630798)
# 	Symbol: t (confidence: 0.9506101012229919)
# 	Symbol: a (confidence: 0.9849451780319214)
# 	Symbol: n (confidence: 0.9867748022079468)
# 	Symbol: d (confidence: 0.994730532169342)
# 	Symbol: i (confidence: 0.9933246970176697)
# 	Symbol: n (confidence: 0.9955071210861206)
# 	Symbol: g (confidence: 0.9905961155891418)
# Word text: our (confidence: 0.8855712413787842)
# 	Symbol: o (confidence: 0.8680111765861511)
# 	Symbol: u (confidence: 0.8858685493469238)
# 	Symbol: r (confidence: 0.9028339385986328)
# Word text: Thoughts (confidence: 0.9697550535202026)
# 	Symbol: T (confidence: 0.9791855812072754)
# 	Symbol: h (confidence: 0.9543341398239136)
# 	Symbol: o (confidence: 0.9357860684394836)
# 	Symbol: u (confidence: 0.9560452699661255)
# 	Symbol: g (confidence: 0.9907975792884827)
# 	Symbol: h (confidence: 0.9854890704154968)
# 	Symbol: t (confidence: 0.9876774549484253)
# 	Symbol: s (confidence: 0.9687255024909973)
# Word text: & (confidence: 0.8746137022972107)
# 	Symbol: & (confidence: 0.8746137022972107)
# Word text: Emotions (confidence: 0.8480482697486877)
# 	Symbol: E (confidence: 0.9515601396560669)
# 	Symbol: m (confidence: 0.9154983162879944)
# 	Symbol: o (confidence: 0.7298598885536194)
# 	Symbol: t (confidence: 0.8098284602165222)
# 	Symbol: i (confidence: 0.8117455840110779)
# 	Symbol: o (confidence: 0.8447625041007996)
# 	Symbol: n (confidence: 0.8210760951042175)
# 	Symbol: s (confidence: 0.9000549912452698)
#
# Block confidence: 0.9588720798492432
#
# Paragraph confidence: 0.9588720798492432
# Word text: # (confidence: 0.9446540474891663)
# 	Symbol: # (confidence: 0.9446540474891663)
# Word text: 4 (confidence: 0.9730901122093201)
# 	Symbol: 4 (confidence: 0.9730901122093201)
#
# Block confidence: 0.870684802532196
#
# Paragraph confidence: 0.870684802532196
# Word text: Cultivating (confidence: 0.847760796546936)
# 	Symbol: C (confidence: 0.9153745770454407)
# 	Symbol: u (confidence: 0.7864477038383484)
# 	Symbol: l (confidence: 0.8808948397636414)
# 	Symbol: t (confidence: 0.7994632720947266)
# 	Symbol: i (confidence: 0.9451465010643005)
# 	Symbol: v (confidence: 0.9516837000846863)
# 	Symbol: a (confidence: 0.9695152640342712)
# 	Symbol: t (confidence: 0.6326865553855896)
# 	Symbol: i (confidence: 0.718242347240448)
# 	Symbol: n (confidence: 0.8075610399246216)
# 	Symbol: g (confidence: 0.9183528423309326)
# Word text: Love (confidence: 0.9551804661750793)
# 	Symbol: L (confidence: 0.8925766348838806)
# 	Symbol: o (confidence: 0.9912222027778625)
# 	Symbol: v (confidence: 0.9776502847671509)
# 	Symbol: e (confidence: 0.9592726826667786)
# Word text: - (confidence: 0.7356284856796265)
# 	Symbol: - (confidence: 0.7356284856796265)
# Word text: Kindness (confidence: 0.8768395781517029)
# 	Symbol: K (confidence: 0.6164185404777527)
# 	Symbol: i (confidence: 0.9387891292572021)
# 	Symbol: n (confidence: 0.8736892342567444)
# 	Symbol: d (confidence: 0.9425827860832214)
# 	Symbol: n (confidence: 0.6929819583892822)
# 	Symbol: e (confidence: 0.9864453077316284)
# 	Symbol: s (confidence: 0.9858409762382507)
# 	Symbol: s (confidence: 0.9779688119888306)
#
# Block confidence: 0.7385870218276978
#
# Paragraph confidence: 0.7385870218276978
# Word text: # (confidence: 0.5130415558815002)
# 	Symbol: # (confidence: 0.5130415558815002)
# Word text: 5 (confidence: 0.9641324877738953)
# 	Symbol: 5 (confidence: 0.9641324877738953)
#
# Block confidence: 0.9559946656227112
#
# Paragraph confidence: 0.9559946656227112
# Word text: Willingness (confidence: 0.8987463116645813)
# 	Symbol: W (confidence: 0.682076096534729)
# 	Symbol: i (confidence: 0.7499268054962158)
# 	Symbol: l (confidence: 0.8018860816955566)
# 	Symbol: l (confidence: 0.8802990317344666)
# 	Symbol: i (confidence: 0.9511761665344238)
# 	Symbol: n (confidence: 0.9328903555870056)
# 	Symbol: g (confidence: 0.981497049331665)
# 	Symbol: n (confidence: 0.9297181367874146)
# 	Symbol: e (confidence: 0.9955286979675293)
# 	Symbol: s (confidence: 0.9940912127494812)
# 	Symbol: s (confidence: 0.9871200323104858)
# Word text: to (confidence: 0.9523419141769409)
# 	Symbol: t (confidence: 0.9289516806602478)
# 	Symbol: o (confidence: 0.9757322072982788)
# Word text: be (confidence: 0.9881144165992737)
# 	Symbol: b (confidence: 0.9857697486877441)
# 	Symbol: e (confidence: 0.9904590845108032)
# Word text: with (confidence: 0.9837067127227783)
# 	Symbol: w (confidence: 0.9844921231269836)
# 	Symbol: i (confidence: 0.9845516681671143)
# 	Symbol: t (confidence: 0.9834995269775391)
# 	Symbol: h (confidence: 0.9822835326194763)
# Word text: things (confidence: 0.989860475063324)
# 	Symbol: t (confidence: 0.9886478185653687)
# 	Symbol: h (confidence: 0.9876397848129272)
# 	Symbol: i (confidence: 0.9888923168182373)
# 	Symbol: n (confidence: 0.9950031042098999)
# 	Symbol: g (confidence: 0.9907655119895935)
# 	Symbol: s (confidence: 0.9882143139839172)
# Word text: as (confidence: 0.9897071123123169)
# 	Symbol: a (confidence: 0.990496039390564)
# 	Symbol: s (confidence: 0.9889182448387146)
# Word text: they (confidence: 0.9894613027572632)
# 	Symbol: t (confidence: 0.9893825650215149)
# 	Symbol: h (confidence: 0.9897408485412598)
# 	Symbol: e (confidence: 0.9902485013008118)
# 	Symbol: y (confidence: 0.9884732365608215)
# Word text: are (confidence: 0.9751488566398621)
# 	Symbol: a (confidence: 0.990490734577179)
# 	Symbol: r (confidence: 0.9511170983314514)
# 	Symbol: e (confidence: 0.9838387370109558)
#
# Block confidence: 0.8857520818710327
#
# Paragraph confidence: 0.8857520818710327
# Word text: # (confidence: 0.8133246302604675)
# 	Symbol: # (confidence: 0.8133246302604675)
# Word text: 6 (confidence: 0.9581795334815979)
# 	Symbol: 6 (confidence: 0.9581795334815979)
#
# Block confidence: 0.9028476476669312
#
# Paragraph confidence: 0.9028476476669312
# Word text: Indining (confidence: 0.8631616234779358)
# 	Symbol: I (confidence: 0.6918169260025024)
# 	Symbol: n (confidence: 0.8539853096008301)
# 	Symbol: d (confidence: 0.6775365471839905)
# 	Symbol: i (confidence: 0.9353086352348328)
# 	Symbol: n (confidence: 0.8620263934135437)
# 	Symbol: i (confidence: 0.953195333480835)
# 	Symbol: n (confidence: 0.9578486084938049)
# 	Symbol: g (confidence: 0.9735754132270813)
# Word text: mind (confidence: 0.8610168099403381)
# 	Symbol: m (confidence: 0.5931780338287354)
# 	Symbol: i (confidence: 0.9511807560920715)
# 	Symbol: n (confidence: 0.9170612096786499)
# 	Symbol: d (confidence: 0.982647180557251)
# Word text: towards (confidence: 0.9679595232009888)
# 	Symbol: t (confidence: 0.9530195593833923)
# 	Symbol: o (confidence: 0.9851903915405273)
# 	Symbol: w (confidence: 0.9678465723991394)
# 	Symbol: a (confidence: 0.9787442684173584)
# 	Symbol: r (confidence: 0.9678663015365601)
# 	Symbol: d (confidence: 0.9629518985748291)
# 	Symbol: s (confidence: 0.9600974917411804)
# Word text: Joy (confidence: 0.9223905801773071)
# 	Symbol: J (confidence: 0.9317964911460876)
# 	Symbol: o (confidence: 0.9541005492210388)
# 	Symbol: y (confidence: 0.8812747597694397)
# Word text: . (confidence: 0.8732468485832214)
# 	Symbol: . (confidence: 0.8732468485832214)

# %%
print(response)
# Out:
# text_annotations {
#   locale: "en"
#   description: "#1\nWhat is Mindfulness\n#2\nHabits of Mind\n#3\nUnderstanding our Thoughts & Emotions\n#4\nCultivating Love - Kindness\n#5\nWillingness to be with things as they are\n#6\nIndining mind towards Joy."
#   bounding_poly {
#     vertices {
#       x: 207
#       y: 217
#     }
#     vertices {
#       x: 1402
#       y: 217
#     }
#     vertices {
#       x: 1402
#       y: 973
#     }
#     vertices {
#       x: 207
#       y: 973
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 210
#       y: 218
#     }
#     vertices {
#       x: 241
#       y: 218
#     }
#     vertices {
#       x: 241
#       y: 260
#     }
#     vertices {
#       x: 210
#       y: 260
#     }
#   }
# }
# text_annotations {
#   description: "1"
#   bounding_poly {
#     vertices {
#       x: 256
#       y: 217
#     }
#     vertices {
#       x: 282
#       y: 217
#     }
#     vertices {
#       x: 282
#       y: 259
#     }
#     vertices {
#       x: 256
#       y: 259
#     }
#   }
# }
# text_annotations {
#   description: "What"
#   bounding_poly {
#     vertices {
#       x: 367
#       y: 218
#     }
#     vertices {
#       x: 483
#       y: 218
#     }
#     vertices {
#       x: 483
#       y: 264
#     }
#     vertices {
#       x: 367
#       y: 264
#     }
#   }
# }
# text_annotations {
#   description: "is"
#   bounding_poly {
#     vertices {
#       x: 509
#       y: 218
#     }
#     vertices {
#       x: 555
#       y: 218
#     }
#     vertices {
#       x: 555
#       y: 264
#     }
#     vertices {
#       x: 509
#       y: 264
#     }
#   }
# }
# text_annotations {
#   description: "Mindfulness"
#   bounding_poly {
#     vertices {
#       x: 580
#       y: 218
#     }
#     vertices {
#       x: 866
#       y: 218
#     }
#     vertices {
#       x: 866
#       y: 264
#     }
#     vertices {
#       x: 580
#       y: 264
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 211
#       y: 363
#     }
#     vertices {
#       x: 252
#       y: 361
#     }
#     vertices {
#       x: 254
#       y: 409
#     }
#     vertices {
#       x: 213
#       y: 411
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 253
#       y: 360
#     }
#     vertices {
#       x: 298
#       y: 358
#     }
#     vertices {
#       x: 300
#       y: 406
#     }
#     vertices {
#       x: 255
#       y: 408
#     }
#   }
# }
# text_annotations {
#   description: "Habits"
#   bounding_poly {
#     vertices {
#       x: 380
#       y: 363
#     }
#     vertices {
#       x: 532
#       y: 367
#     }
#     vertices {
#       x: 531
#       y: 402
#     }
#     vertices {
#       x: 379
#       y: 398
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 559
#       y: 368
#     }
#     vertices {
#       x: 600
#       y: 369
#     }
#     vertices {
#       x: 599
#       y: 404
#     }
#     vertices {
#       x: 558
#       y: 403
#     }
#   }
# }
# text_annotations {
#   description: "Mind"
#   bounding_poly {
#     vertices {
#       x: 619
#       y: 370
#     }
#     vertices {
#       x: 727
#       y: 373
#     }
#     vertices {
#       x: 726
#       y: 407
#     }
#     vertices {
#       x: 618
#       y: 404
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 215
#       y: 502
#     }
#     vertices {
#       x: 252
#       y: 502
#     }
#     vertices {
#       x: 252
#       y: 553
#     }
#     vertices {
#       x: 215
#       y: 553
#     }
#   }
# }
# text_annotations {
#   description: "3"
#   bounding_poly {
#     vertices {
#       x: 257
#       y: 502
#     }
#     vertices {
#       x: 290
#       y: 502
#     }
#     vertices {
#       x: 290
#       y: 553
#     }
#     vertices {
#       x: 257
#       y: 553
#     }
#   }
# }
# text_annotations {
#   description: "Understanding"
#   bounding_poly {
#     vertices {
#       x: 386
#       y: 498
#     }
#     vertices {
#       x: 721
#       y: 496
#     }
#     vertices {
#       x: 721
#       y: 555
#     }
#     vertices {
#       x: 386
#       y: 557
#     }
#   }
# }
# text_annotations {
#   description: "our"
#   bounding_poly {
#     vertices {
#       x: 753
#       y: 496
#     }
#     vertices {
#       x: 833
#       y: 495
#     }
#     vertices {
#       x: 833
#       y: 553
#     }
#     vertices {
#       x: 753
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "Thoughts"
#   bounding_poly {
#     vertices {
#       x: 849
#       y: 495
#     }
#     vertices {
#       x: 1046
#       y: 494
#     }
#     vertices {
#       x: 1046
#       y: 553
#     }
#     vertices {
#       x: 849
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 1066
#       y: 494
#     }
#     vertices {
#       x: 1101
#       y: 494
#     }
#     vertices {
#       x: 1101
#       y: 552
#     }
#     vertices {
#       x: 1066
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "Emotions"
#   bounding_poly {
#     vertices {
#       x: 1120
#       y: 493
#     }
#     vertices {
#       x: 1321
#       y: 492
#     }
#     vertices {
#       x: 1321
#       y: 551
#     }
#     vertices {
#       x: 1120
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 224
#       y: 640
#     }
#     vertices {
#       x: 256
#       y: 640
#     }
#     vertices {
#       x: 257
#       y: 688
#     }
#     vertices {
#       x: 225
#       y: 688
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 257
#       y: 639
#     }
#     vertices {
#       x: 296
#       y: 639
#     }
#     vertices {
#       x: 297
#       y: 687
#     }
#     vertices {
#       x: 258
#       y: 687
#     }
#   }
# }
# text_annotations {
#   description: "Cultivating"
#   bounding_poly {
#     vertices {
#       x: 377
#       y: 643
#     }
#     vertices {
#       x: 631
#       y: 643
#     }
#     vertices {
#       x: 631
#       y: 692
#     }
#     vertices {
#       x: 377
#       y: 692
#     }
#   }
# }
# text_annotations {
#   description: "Love"
#   bounding_poly {
#     vertices {
#       x: 666
#       y: 643
#     }
#     vertices {
#       x: 762
#       y: 643
#     }
#     vertices {
#       x: 762
#       y: 692
#     }
#     vertices {
#       x: 666
#       y: 692
#     }
#   }
# }
# text_annotations {
#   description: "-"
#   bounding_poly {
#     vertices {
#       x: 777
#       y: 643
#     }
#     vertices {
#       x: 804
#       y: 643
#     }
#     vertices {
#       x: 804
#       y: 692
#     }
#     vertices {
#       x: 777
#       y: 692
#     }
#   }
# }
# text_annotations {
#   description: "Kindness"
#   bounding_poly {
#     vertices {
#       x: 807
#       y: 643
#     }
#     vertices {
#       x: 1008
#       y: 643
#     }
#     vertices {
#       x: 1008
#       y: 692
#     }
#     vertices {
#       x: 807
#       y: 692
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 220
#       y: 778
#     }
#     vertices {
#       x: 255
#       y: 778
#     }
#     vertices {
#       x: 255
#       y: 824
#     }
#     vertices {
#       x: 220
#       y: 824
#     }
#   }
# }
# text_annotations {
#   description: "5"
#   bounding_poly {
#     vertices {
#       x: 254
#       y: 777
#     }
#     vertices {
#       x: 292
#       y: 777
#     }
#     vertices {
#       x: 292
#       y: 823
#     }
#     vertices {
#       x: 254
#       y: 823
#     }
#   }
# }
# text_annotations {
#   description: "Willingness"
#   bounding_poly {
#     vertices {
#       x: 390
#       y: 782
#     }
#     vertices {
#       x: 660
#       y: 785
#     }
#     vertices {
#       x: 660
#       y: 829
#     }
#     vertices {
#       x: 390
#       y: 826
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 693
#       y: 785
#     }
#     vertices {
#       x: 739
#       y: 785
#     }
#     vertices {
#       x: 739
#       y: 829
#     }
#     vertices {
#       x: 693
#       y: 829
#     }
#   }
# }
# text_annotations {
#   description: "be"
#   bounding_poly {
#     vertices {
#       x: 756
#       y: 786
#     }
#     vertices {
#       x: 809
#       y: 787
#     }
#     vertices {
#       x: 809
#       y: 830
#     }
#     vertices {
#       x: 756
#       y: 829
#     }
#   }
# }
# text_annotations {
#   description: "with"
#   bounding_poly {
#     vertices {
#       x: 834
#       y: 786
#     }
#     vertices {
#       x: 923
#       y: 787
#     }
#     vertices {
#       x: 923
#       y: 831
#     }
#     vertices {
#       x: 834
#       y: 830
#     }
#   }
# }
# text_annotations {
#   description: "things"
#   bounding_poly {
#     vertices {
#       x: 950
#       y: 788
#     }
#     vertices {
#       x: 1096
#       y: 789
#     }
#     vertices {
#       x: 1096
#       y: 832
#     }
#     vertices {
#       x: 950
#       y: 831
#     }
#   }
# }
# text_annotations {
#   description: "as"
#   bounding_poly {
#     vertices {
#       x: 1124
#       y: 790
#     }
#     vertices {
#       x: 1179
#       y: 791
#     }
#     vertices {
#       x: 1179
#       y: 834
#     }
#     vertices {
#       x: 1124
#       y: 833
#     }
#   }
# }
# text_annotations {
#   description: "they"
#   bounding_poly {
#     vertices {
#       x: 1204
#       y: 790
#     }
#     vertices {
#       x: 1303
#       y: 791
#     }
#     vertices {
#       x: 1303
#       y: 835
#     }
#     vertices {
#       x: 1204
#       y: 834
#     }
#   }
# }
# text_annotations {
#   description: "are"
#   bounding_poly {
#     vertices {
#       x: 1323
#       y: 792
#     }
#     vertices {
#       x: 1402
#       y: 793
#     }
#     vertices {
#       x: 1402
#       y: 836
#     }
#     vertices {
#       x: 1323
#       y: 835
#     }
#   }
# }
# text_annotations {
#   description: "#"
#   bounding_poly {
#     vertices {
#       x: 207
#       y: 916
#     }
#     vertices {
#       x: 253
#       y: 916
#     }
#     vertices {
#       x: 253
#       y: 966
#     }
#     vertices {
#       x: 207
#       y: 966
#     }
#   }
# }
# text_annotations {
#   description: "6"
#   bounding_poly {
#     vertices {
#       x: 253
#       y: 916
#     }
#     vertices {
#       x: 292
#       y: 916
#     }
#     vertices {
#       x: 292
#       y: 966
#     }
#     vertices {
#       x: 253
#       y: 966
#     }
#   }
# }
# text_annotations {
#   description: "Indining"
#   bounding_poly {
#     vertices {
#       x: 382
#       y: 924
#     }
#     vertices {
#       x: 580
#       y: 924
#     }
#     vertices {
#       x: 580
#       y: 973
#     }
#     vertices {
#       x: 382
#       y: 973
#     }
#   }
# }
# text_annotations {
#   description: "mind"
#   bounding_poly {
#     vertices {
#       x: 600
#       y: 924
#     }
#     vertices {
#       x: 719
#       y: 924
#     }
#     vertices {
#       x: 719
#       y: 973
#     }
#     vertices {
#       x: 600
#       y: 973
#     }
#   }
# }
# text_annotations {
#   description: "towards"
#   bounding_poly {
#     vertices {
#       x: 750
#       y: 924
#     }
#     vertices {
#       x: 923
#       y: 924
#     }
#     vertices {
#       x: 923
#       y: 973
#     }
#     vertices {
#       x: 750
#       y: 973
#     }
#   }
# }
# text_annotations {
#   description: "Joy"
#   bounding_poly {
#     vertices {
#       x: 942
#       y: 924
#     }
#     vertices {
#       x: 1031
#       y: 924
#     }
#     vertices {
#       x: 1031
#       y: 973
#     }
#     vertices {
#       x: 942
#       y: 973
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 1026
#       y: 924
#     }
#     vertices {
#       x: 1052
#       y: 924
#     }
#     vertices {
#       x: 1052
#       y: 973
#     }
#     vertices {
#       x: 1026
#       y: 973
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 0.9276092052459717
#       }
#     }
#     width: 1600
#     height: 1200
#     blocks {
#       bounding_box {
#         vertices {
#           x: 210
#           y: 217
#         }
#         vertices {
#           x: 282
#           y: 217
#         }
#         vertices {
#           x: 282
#           y: 260
#         }
#         vertices {
#           x: 210
#           y: 260
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 210
#             y: 217
#           }
#           vertices {
#             x: 282
#             y: 217
#           }
#           vertices {
#             x: 282
#             y: 260
#           }
#           vertices {
#             x: 210
#             y: 260
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 210
#               y: 218
#             }
#             vertices {
#               x: 241
#               y: 218
#             }
#             vertices {
#               x: 241
#               y: 260
#             }
#             vertices {
#               x: 210
#               y: 260
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 210
#                 y: 218
#               }
#               vertices {
#                 x: 241
#                 y: 218
#               }
#               vertices {
#                 x: 241
#                 y: 260
#               }
#               vertices {
#                 x: 210
#                 y: 260
#               }
#             }
#             text: "#"
#             confidence: 0.8970488905906677
#           }
#           confidence: 0.8970488905906677
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 256
#               y: 217
#             }
#             vertices {
#               x: 282
#               y: 217
#             }
#             vertices {
#               x: 282
#               y: 259
#             }
#             vertices {
#               x: 256
#               y: 259
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 256
#                 y: 217
#               }
#               vertices {
#                 x: 282
#                 y: 217
#               }
#               vertices {
#                 x: 282
#                 y: 259
#               }
#               vertices {
#                 x: 256
#                 y: 259
#               }
#             }
#             text: "1"
#             confidence: 0.9878649115562439
#           }
#           confidence: 0.9878649115562439
#         }
#         confidence: 0.9424569010734558
#       }
#       block_type: TEXT
#       confidence: 0.9424569010734558
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 367
#           y: 218
#         }
#         vertices {
#           x: 866
#           y: 218
#         }
#         vertices {
#           x: 866
#           y: 264
#         }
#         vertices {
#           x: 367
#           y: 264
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 367
#             y: 218
#           }
#           vertices {
#             x: 866
#             y: 218
#           }
#           vertices {
#             x: 866
#             y: 264
#           }
#           vertices {
#             x: 367
#             y: 264
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 367
#               y: 218
#             }
#             vertices {
#               x: 483
#               y: 218
#             }
#             vertices {
#               x: 483
#               y: 264
#             }
#             vertices {
#               x: 367
#               y: 264
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 367
#                 y: 218
#               }
#               vertices {
#                 x: 407
#                 y: 218
#               }
#               vertices {
#                 x: 407
#                 y: 264
#               }
#               vertices {
#                 x: 367
#                 y: 264
#               }
#             }
#             text: "W"
#             confidence: 0.8481331467628479
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 400
#                 y: 218
#               }
#               vertices {
#                 x: 433
#                 y: 218
#               }
#               vertices {
#                 x: 433
#                 y: 264
#               }
#               vertices {
#                 x: 400
#                 y: 264
#               }
#             }
#             text: "h"
#             confidence: 0.9859771728515625
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 431
#                 y: 218
#               }
#               vertices {
#                 x: 464
#                 y: 218
#               }
#               vertices {
#                 x: 464
#                 y: 264
#               }
#               vertices {
#                 x: 431
#                 y: 264
#               }
#             }
#             text: "a"
#             confidence: 0.9818291664123535
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 456
#                 y: 218
#               }
#               vertices {
#                 x: 483
#                 y: 218
#               }
#               vertices {
#                 x: 483
#                 y: 264
#               }
#               vertices {
#                 x: 456
#                 y: 264
#               }
#             }
#             text: "t"
#             confidence: 0.9675832390785217
#           }
#           confidence: 0.945880651473999
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 509
#               y: 218
#             }
#             vertices {
#               x: 555
#               y: 218
#             }
#             vertices {
#               x: 555
#               y: 264
#             }
#             vertices {
#               x: 509
#               y: 264
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 509
#                 y: 218
#               }
#               vertices {
#                 x: 530
#                 y: 218
#               }
#               vertices {
#                 x: 530
#                 y: 264
#               }
#               vertices {
#                 x: 509
#                 y: 264
#               }
#             }
#             text: "i"
#             confidence: 0.95005202293396
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 526
#                 y: 218
#               }
#               vertices {
#                 x: 555
#                 y: 218
#               }
#               vertices {
#                 x: 555
#                 y: 264
#               }
#               vertices {
#                 x: 526
#                 y: 264
#               }
#             }
#             text: "s"
#             confidence: 0.9632085561752319
#           }
#           confidence: 0.956630289554596
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 580
#               y: 218
#             }
#             vertices {
#               x: 866
#               y: 218
#             }
#             vertices {
#               x: 866
#               y: 264
#             }
#             vertices {
#               x: 580
#               y: 264
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 580
#                 y: 218
#               }
#               vertices {
#                 x: 628
#                 y: 218
#               }
#               vertices {
#                 x: 628
#                 y: 264
#               }
#               vertices {
#                 x: 580
#                 y: 264
#               }
#             }
#             text: "M"
#             confidence: 0.6991844177246094
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 620
#                 y: 218
#               }
#               vertices {
#                 x: 644
#                 y: 218
#               }
#               vertices {
#                 x: 644
#                 y: 264
#               }
#               vertices {
#                 x: 620
#                 y: 264
#               }
#             }
#             text: "i"
#             confidence: 0.9543477296829224
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 639
#                 y: 218
#               }
#               vertices {
#                 x: 669
#                 y: 218
#               }
#               vertices {
#                 x: 669
#                 y: 264
#               }
#               vertices {
#                 x: 639
#                 y: 264
#               }
#             }
#             text: "n"
#             confidence: 0.9411085247993469
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 665
#                 y: 218
#               }
#               vertices {
#                 x: 700
#                 y: 218
#               }
#               vertices {
#                 x: 700
#                 y: 264
#               }
#               vertices {
#                 x: 665
#                 y: 264
#               }
#             }
#             text: "d"
#             confidence: 0.9776654243469238
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 697
#                 y: 218
#               }
#               vertices {
#                 x: 727
#                 y: 218
#               }
#               vertices {
#                 x: 727
#                 y: 264
#               }
#               vertices {
#                 x: 697
#                 y: 264
#               }
#             }
#             text: "f"
#             confidence: 0.9693295955657959
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 720
#                 y: 218
#               }
#               vertices {
#                 x: 754
#                 y: 218
#               }
#               vertices {
#                 x: 754
#                 y: 264
#               }
#               vertices {
#                 x: 720
#                 y: 264
#               }
#             }
#             text: "u"
#             confidence: 0.9358998537063599
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 750
#                 y: 218
#               }
#               vertices {
#                 x: 775
#                 y: 218
#               }
#               vertices {
#                 x: 775
#                 y: 264
#               }
#               vertices {
#                 x: 750
#                 y: 264
#               }
#             }
#             text: "l"
#             confidence: 0.985048770904541
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 771
#                 y: 218
#               }
#               vertices {
#                 x: 802
#                 y: 218
#               }
#               vertices {
#                 x: 802
#                 y: 264
#               }
#               vertices {
#                 x: 771
#                 y: 264
#               }
#             }
#             text: "n"
#             confidence: 0.9792196750640869
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 800
#                 y: 218
#               }
#               vertices {
#                 x: 826
#                 y: 218
#               }
#               vertices {
#                 x: 826
#                 y: 264
#               }
#               vertices {
#                 x: 800
#                 y: 264
#               }
#             }
#             text: "e"
#             confidence: 0.9965243935585022
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 821
#                 y: 218
#               }
#               vertices {
#                 x: 843
#                 y: 218
#               }
#               vertices {
#                 x: 843
#                 y: 264
#               }
#               vertices {
#                 x: 821
#                 y: 264
#               }
#             }
#             text: "s"
#             confidence: 0.9913613200187683
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 840
#                 y: 218
#               }
#               vertices {
#                 x: 866
#                 y: 218
#               }
#               vertices {
#                 x: 866
#                 y: 264
#               }
#               vertices {
#                 x: 840
#                 y: 264
#               }
#             }
#             text: "s"
#             confidence: 0.9814419150352478
#           }
#           confidence: 0.9464665055274963
#         }
#         confidence: 0.9475244283676147
#       }
#       block_type: TEXT
#       confidence: 0.9475244283676147
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 211
#           y: 362
#         }
#         vertices {
#           x: 298
#           y: 358
#         }
#         vertices {
#           x: 300
#           y: 407
#         }
#         vertices {
#           x: 213
#           y: 411
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 211
#             y: 362
#           }
#           vertices {
#             x: 298
#             y: 358
#           }
#           vertices {
#             x: 300
#             y: 407
#           }
#           vertices {
#             x: 213
#             y: 411
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 211
#               y: 363
#             }
#             vertices {
#               x: 252
#               y: 361
#             }
#             vertices {
#               x: 254
#               y: 409
#             }
#             vertices {
#               x: 213
#               y: 411
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 211
#                 y: 363
#               }
#               vertices {
#                 x: 252
#                 y: 361
#               }
#               vertices {
#                 x: 254
#                 y: 409
#               }
#               vertices {
#                 x: 213
#                 y: 411
#               }
#             }
#             text: "#"
#             confidence: 0.7083378434181213
#           }
#           confidence: 0.7083378434181213
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 253
#               y: 360
#             }
#             vertices {
#               x: 298
#               y: 358
#             }
#             vertices {
#               x: 300
#               y: 406
#             }
#             vertices {
#               x: 255
#               y: 408
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 253
#                 y: 360
#               }
#               vertices {
#                 x: 298
#                 y: 358
#               }
#               vertices {
#                 x: 300
#                 y: 406
#               }
#               vertices {
#                 x: 255
#                 y: 408
#               }
#             }
#             text: "2"
#             confidence: 0.961284875869751
#           }
#           confidence: 0.961284875869751
#         }
#         confidence: 0.8348113298416138
#       }
#       block_type: TEXT
#       confidence: 0.8348113298416138
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 380
#           y: 363
#         }
#         vertices {
#           x: 727
#           y: 372
#         }
#         vertices {
#           x: 726
#           y: 407
#         }
#         vertices {
#           x: 379
#           y: 398
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 380
#             y: 363
#           }
#           vertices {
#             x: 727
#             y: 372
#           }
#           vertices {
#             x: 726
#             y: 407
#           }
#           vertices {
#             x: 379
#             y: 398
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 380
#               y: 363
#             }
#             vertices {
#               x: 532
#               y: 367
#             }
#             vertices {
#               x: 531
#               y: 402
#             }
#             vertices {
#               x: 379
#               y: 398
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 380
#                 y: 364
#               }
#               vertices {
#                 x: 412
#                 y: 365
#               }
#               vertices {
#                 x: 411
#                 y: 399
#               }
#               vertices {
#                 x: 379
#                 y: 398
#               }
#             }
#             text: "H"
#             confidence: 0.9608584046363831
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 417
#                 y: 364
#               }
#               vertices {
#                 x: 446
#                 y: 365
#               }
#               vertices {
#                 x: 445
#                 y: 399
#               }
#               vertices {
#                 x: 416
#                 y: 398
#               }
#             }
#             text: "a"
#             confidence: 0.9833772778511047
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 444
#                 y: 365
#               }
#               vertices {
#                 x: 472
#                 y: 366
#               }
#               vertices {
#                 x: 471
#                 y: 400
#               }
#               vertices {
#                 x: 443
#                 y: 399
#               }
#             }
#             text: "b"
#             confidence: 0.9801293015480042
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 471
#                 y: 366
#               }
#               vertices {
#                 x: 492
#                 y: 367
#               }
#               vertices {
#                 x: 491
#                 y: 401
#               }
#               vertices {
#                 x: 470
#                 y: 400
#               }
#             }
#             text: "i"
#             confidence: 0.9958483576774597
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 486
#                 y: 366
#               }
#               vertices {
#                 x: 512
#                 y: 367
#               }
#               vertices {
#                 x: 511
#                 y: 401
#               }
#               vertices {
#                 x: 485
#                 y: 400
#               }
#             }
#             text: "t"
#             confidence: 0.9907765984535217
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 508
#                 y: 367
#               }
#               vertices {
#                 x: 532
#                 y: 368
#               }
#               vertices {
#                 x: 531
#                 y: 402
#               }
#               vertices {
#                 x: 507
#                 y: 401
#               }
#             }
#             text: "s"
#             confidence: 0.9852966070175171
#           }
#           confidence: 0.9827144145965576
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 559
#               y: 368
#             }
#             vertices {
#               x: 600
#               y: 369
#             }
#             vertices {
#               x: 599
#               y: 404
#             }
#             vertices {
#               x: 558
#               y: 403
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 559
#                 y: 368
#               }
#               vertices {
#                 x: 580
#                 y: 369
#               }
#               vertices {
#                 x: 579
#                 y: 403
#               }
#               vertices {
#                 x: 558
#                 y: 402
#               }
#             }
#             text: "o"
#             confidence: 0.9455196857452393
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 577
#                 y: 369
#               }
#               vertices {
#                 x: 600
#                 y: 370
#               }
#               vertices {
#                 x: 599
#                 y: 404
#               }
#               vertices {
#                 x: 576
#                 y: 403
#               }
#             }
#             text: "f"
#             confidence: 0.9702737927436829
#           }
#           confidence: 0.9578967094421387
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 619
#               y: 370
#             }
#             vertices {
#               x: 727
#               y: 373
#             }
#             vertices {
#               x: 726
#               y: 407
#             }
#             vertices {
#               x: 618
#               y: 404
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 619
#                 y: 370
#               }
#               vertices {
#                 x: 659
#                 y: 371
#               }
#               vertices {
#                 x: 658
#                 y: 405
#               }
#               vertices {
#                 x: 618
#                 y: 404
#               }
#             }
#             text: "M"
#             confidence: 0.9587565660476685
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 659
#                 y: 371
#               }
#               vertices {
#                 x: 678
#                 y: 371
#               }
#               vertices {
#                 x: 677
#                 y: 405
#               }
#               vertices {
#                 x: 658
#                 y: 405
#               }
#             }
#             text: "i"
#             confidence: 0.9635127782821655
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 673
#                 y: 371
#               }
#               vertices {
#                 x: 699
#                 y: 372
#               }
#               vertices {
#                 x: 698
#                 y: 406
#               }
#               vertices {
#                 x: 672
#                 y: 405
#               }
#             }
#             text: "n"
#             confidence: 0.6933403015136719
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 695
#                 y: 372
#               }
#               vertices {
#                 x: 727
#                 y: 373
#               }
#               vertices {
#                 x: 726
#                 y: 407
#               }
#               vertices {
#                 x: 694
#                 y: 406
#               }
#             }
#             text: "d"
#             confidence: 0.8915984630584717
#           }
#           confidence: 0.8768020272254944
#         }
#         confidence: 0.9432740211486816
#       }
#       block_type: TEXT
#       confidence: 0.9432740211486816
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 215
#           y: 502
#         }
#         vertices {
#           x: 290
#           y: 502
#         }
#         vertices {
#           x: 290
#           y: 553
#         }
#         vertices {
#           x: 215
#           y: 553
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 215
#             y: 502
#           }
#           vertices {
#             x: 290
#             y: 502
#           }
#           vertices {
#             x: 290
#             y: 553
#           }
#           vertices {
#             x: 215
#             y: 553
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 215
#               y: 502
#             }
#             vertices {
#               x: 252
#               y: 502
#             }
#             vertices {
#               x: 252
#               y: 553
#             }
#             vertices {
#               x: 215
#               y: 553
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 215
#                 y: 502
#               }
#               vertices {
#                 x: 252
#                 y: 502
#               }
#               vertices {
#                 x: 252
#                 y: 553
#               }
#               vertices {
#                 x: 215
#                 y: 553
#               }
#             }
#             text: "#"
#             confidence: 0.6056626439094543
#           }
#           confidence: 0.6056626439094543
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 257
#               y: 502
#             }
#             vertices {
#               x: 290
#               y: 502
#             }
#             vertices {
#               x: 290
#               y: 553
#             }
#             vertices {
#               x: 257
#               y: 553
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 257
#                 y: 502
#               }
#               vertices {
#                 x: 290
#                 y: 502
#               }
#               vertices {
#                 x: 290
#                 y: 553
#               }
#               vertices {
#                 x: 257
#                 y: 553
#               }
#             }
#             text: "3"
#             confidence: 0.9723243713378906
#           }
#           confidence: 0.9723243713378906
#         }
#         confidence: 0.7889934778213501
#       }
#       block_type: TEXT
#       confidence: 0.7889934778213501
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 386
#           y: 498
#         }
#         vertices {
#           x: 1321
#           y: 491
#         }
#         vertices {
#           x: 1321
#           y: 550
#         }
#         vertices {
#           x: 386
#           y: 557
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 386
#             y: 498
#           }
#           vertices {
#             x: 1321
#             y: 491
#           }
#           vertices {
#             x: 1321
#             y: 550
#           }
#           vertices {
#             x: 386
#             y: 557
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 386
#               y: 498
#             }
#             vertices {
#               x: 721
#               y: 496
#             }
#             vertices {
#               x: 721
#               y: 555
#             }
#             vertices {
#               x: 386
#               y: 557
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 386
#                 y: 499
#               }
#               vertices {
#                 x: 421
#                 y: 499
#               }
#               vertices {
#                 x: 421
#                 y: 557
#               }
#               vertices {
#                 x: 386
#                 y: 557
#               }
#             }
#             text: "U"
#             confidence: 0.6658496856689453
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 417
#                 y: 498
#               }
#               vertices {
#                 x: 446
#                 y: 498
#               }
#               vertices {
#                 x: 446
#                 y: 556
#               }
#               vertices {
#                 x: 417
#                 y: 556
#               }
#             }
#             text: "n"
#             confidence: 0.9127954244613647
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 442
#                 y: 498
#               }
#               vertices {
#                 x: 475
#                 y: 498
#               }
#               vertices {
#                 x: 475
#                 y: 556
#               }
#               vertices {
#                 x: 442
#                 y: 556
#               }
#             }
#             text: "d"
#             confidence: 0.9470639824867249
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 470
#                 y: 498
#               }
#               vertices {
#                 x: 500
#                 y: 498
#               }
#               vertices {
#                 x: 500
#                 y: 556
#               }
#               vertices {
#                 x: 470
#                 y: 556
#               }
#             }
#             text: "e"
#             confidence: 0.9861584901809692
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 493
#                 y: 498
#               }
#               vertices {
#                 x: 519
#                 y: 498
#               }
#               vertices {
#                 x: 519
#                 y: 556
#               }
#               vertices {
#                 x: 493
#                 y: 556
#               }
#             }
#             text: "r"
#             confidence: 0.9170764684677124
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 512
#                 y: 498
#               }
#               vertices {
#                 x: 535
#                 y: 498
#               }
#               vertices {
#                 x: 535
#                 y: 556
#               }
#               vertices {
#                 x: 512
#                 y: 556
#               }
#             }
#             text: "s"
#             confidence: 0.9776014685630798
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 535
#                 y: 497
#               }
#               vertices {
#                 x: 560
#                 y: 497
#               }
#               vertices {
#                 x: 560
#                 y: 555
#               }
#               vertices {
#                 x: 535
#                 y: 555
#               }
#             }
#             text: "t"
#             confidence: 0.9506101012229919
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 554
#                 y: 497
#               }
#               vertices {
#                 x: 587
#                 y: 497
#               }
#               vertices {
#                 x: 587
#                 y: 555
#               }
#               vertices {
#                 x: 554
#                 y: 555
#               }
#             }
#             text: "a"
#             confidence: 0.9849451780319214
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 584
#                 y: 497
#               }
#               vertices {
#                 x: 616
#                 y: 497
#               }
#               vertices {
#                 x: 616
#                 y: 555
#               }
#               vertices {
#                 x: 584
#                 y: 555
#               }
#             }
#             text: "n"
#             confidence: 0.9867748022079468
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 609
#                 y: 497
#               }
#               vertices {
#                 x: 642
#                 y: 497
#               }
#               vertices {
#                 x: 642
#                 y: 555
#               }
#               vertices {
#                 x: 609
#                 y: 555
#               }
#             }
#             text: "d"
#             confidence: 0.994730532169342
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 638
#                 y: 497
#               }
#               vertices {
#                 x: 660
#                 y: 497
#               }
#               vertices {
#                 x: 660
#                 y: 555
#               }
#               vertices {
#                 x: 638
#                 y: 555
#               }
#             }
#             text: "i"
#             confidence: 0.9933246970176697
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 660
#                 y: 497
#               }
#               vertices {
#                 x: 689
#                 y: 497
#               }
#               vertices {
#                 x: 689
#                 y: 555
#               }
#               vertices {
#                 x: 660
#                 y: 555
#               }
#             }
#             text: "n"
#             confidence: 0.9955071210861206
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 687
#                 y: 496
#               }
#               vertices {
#                 x: 721
#                 y: 496
#               }
#               vertices {
#                 x: 721
#                 y: 554
#               }
#               vertices {
#                 x: 687
#                 y: 554
#               }
#             }
#             text: "g"
#             confidence: 0.9905961155891418
#           }
#           confidence: 0.9463872313499451
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 753
#               y: 496
#             }
#             vertices {
#               x: 833
#               y: 495
#             }
#             vertices {
#               x: 833
#               y: 553
#             }
#             vertices {
#               x: 753
#               y: 554
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 753
#                 y: 496
#               }
#               vertices {
#                 x: 779
#                 y: 496
#               }
#               vertices {
#                 x: 779
#                 y: 554
#               }
#               vertices {
#                 x: 753
#                 y: 554
#               }
#             }
#             text: "o"
#             confidence: 0.8680111765861511
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 777
#                 y: 496
#               }
#               vertices {
#                 x: 809
#                 y: 496
#               }
#               vertices {
#                 x: 809
#                 y: 554
#               }
#               vertices {
#                 x: 777
#                 y: 554
#               }
#             }
#             text: "u"
#             confidence: 0.8858685493469238
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 806
#                 y: 496
#               }
#               vertices {
#                 x: 833
#                 y: 496
#               }
#               vertices {
#                 x: 833
#                 y: 554
#               }
# ...
#               }
#               vertices {
#                 x: 292
#                 y: 916
#               }
#               vertices {
#                 x: 292
#                 y: 966
#               }
#               vertices {
#                 x: 253
#                 y: 966
#               }
#             }
#             text: "6"
#             confidence: 0.9581795334815979
#           }
#           confidence: 0.9581795334815979
#         }
#         confidence: 0.8857520818710327
#       }
#       block_type: TEXT
#       confidence: 0.8857520818710327
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 382
#           y: 924
#         }
#         vertices {
#           x: 1052
#           y: 924
#         }
#         vertices {
#           x: 1052
#           y: 973
#         }
#         vertices {
#           x: 382
#           y: 973
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 382
#             y: 924
#           }
#           vertices {
#             x: 1052
#             y: 924
#           }
#           vertices {
#             x: 1052
#             y: 973
#           }
#           vertices {
#             x: 382
#             y: 973
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 382
#               y: 924
#             }
#             vertices {
#               x: 580
#               y: 924
#             }
#             vertices {
#               x: 580
#               y: 973
#             }
#             vertices {
#               x: 382
#               y: 973
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 382
#                 y: 924
#               }
#               vertices {
#                 x: 406
#                 y: 924
#               }
#               vertices {
#                 x: 406
#                 y: 973
#               }
#               vertices {
#                 x: 382
#                 y: 973
#               }
#             }
#             text: "I"
#             confidence: 0.6918169260025024
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 400
#                 y: 924
#               }
#               vertices {
#                 x: 428
#                 y: 924
#               }
#               vertices {
#                 x: 428
#                 y: 973
#               }
#               vertices {
#                 x: 400
#                 y: 973
#               }
#             }
#             text: "n"
#             confidence: 0.8539853096008301
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 431
#                 y: 924
#               }
#               vertices {
#                 x: 464
#                 y: 924
#               }
#               vertices {
#                 x: 464
#                 y: 973
#               }
#               vertices {
#                 x: 431
#                 y: 973
#               }
#             }
#             text: "d"
#             confidence: 0.6775365471839905
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 461
#                 y: 924
#               }
#               vertices {
#                 x: 481
#                 y: 924
#               }
#               vertices {
#                 x: 481
#                 y: 973
#               }
#               vertices {
#                 x: 461
#                 y: 973
#               }
#             }
#             text: "i"
#             confidence: 0.9353086352348328
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 479
#                 y: 924
#               }
#               vertices {
#                 x: 507
#                 y: 924
#               }
#               vertices {
#                 x: 507
#                 y: 973
#               }
#               vertices {
#                 x: 479
#                 y: 973
#               }
#             }
#             text: "n"
#             confidence: 0.8620263934135437
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 508
#                 y: 924
#               }
#               vertices {
#                 x: 528
#                 y: 924
#               }
#               vertices {
#                 x: 528
#                 y: 973
#               }
#               vertices {
#                 x: 508
#                 y: 973
#               }
#             }
#             text: "i"
#             confidence: 0.953195333480835
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 525
#                 y: 924
#               }
#               vertices {
#                 x: 550
#                 y: 924
#               }
#               vertices {
#                 x: 550
#                 y: 973
#               }
#               vertices {
#                 x: 525
#                 y: 973
#               }
#             }
#             text: "n"
#             confidence: 0.9578486084938049
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 548
#                 y: 924
#               }
#               vertices {
#                 x: 580
#                 y: 924
#               }
#               vertices {
#                 x: 580
#                 y: 973
#               }
#               vertices {
#                 x: 548
#                 y: 973
#               }
#             }
#             text: "g"
#             confidence: 0.9735754132270813
#           }
#           confidence: 0.8631616234779358
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 600
#               y: 924
#             }
#             vertices {
#               x: 719
#               y: 924
#             }
#             vertices {
#               x: 719
#               y: 973
#             }
#             vertices {
#               x: 600
#               y: 973
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 600
#                 y: 924
#               }
#               vertices {
#                 x: 647
#                 y: 924
#               }
#               vertices {
#                 x: 647
#                 y: 973
#               }
#               vertices {
#                 x: 600
#                 y: 973
#               }
#             }
#             text: "m"
#             confidence: 0.5931780338287354
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 648
#                 y: 924
#               }
#               vertices {
#                 x: 665
#                 y: 924
#               }
#               vertices {
#                 x: 665
#                 y: 973
#               }
#               vertices {
#                 x: 648
#                 y: 973
#               }
#             }
#             text: "i"
#             confidence: 0.9511807560920715
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 663
#                 y: 924
#               }
#               vertices {
#                 x: 690
#                 y: 924
#               }
#               vertices {
#                 x: 690
#                 y: 973
#               }
#               vertices {
#                 x: 663
#                 y: 973
#               }
#             }
#             text: "n"
#             confidence: 0.9170612096786499
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 688
#                 y: 924
#               }
#               vertices {
#                 x: 719
#                 y: 924
#               }
#               vertices {
#                 x: 719
#                 y: 973
#               }
#               vertices {
#                 x: 688
#                 y: 973
#               }
#             }
#             text: "d"
#             confidence: 0.982647180557251
#           }
#           confidence: 0.8610168099403381
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 750
#               y: 924
#             }
#             vertices {
#               x: 923
#               y: 924
#             }
#             vertices {
#               x: 923
#               y: 973
#             }
#             vertices {
#               x: 750
#               y: 973
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 750
#                 y: 924
#               }
#               vertices {
#                 x: 776
#                 y: 924
#               }
#               vertices {
#                 x: 776
#                 y: 973
#               }
#               vertices {
#                 x: 750
#                 y: 973
#               }
#             }
#             text: "t"
#             confidence: 0.9530195593833923
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 773
#                 y: 924
#               }
#               vertices {
#                 x: 797
#                 y: 924
#               }
#               vertices {
#                 x: 797
#                 y: 973
#               }
#               vertices {
#                 x: 773
#                 y: 973
#               }
#             }
#             text: "o"
#             confidence: 0.9851903915405273
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 794
#                 y: 924
#               }
#               vertices {
#                 x: 828
#                 y: 924
#               }
#               vertices {
#                 x: 828
#                 y: 973
#               }
#               vertices {
#                 x: 794
#                 y: 973
#               }
#             }
#             text: "w"
#             confidence: 0.9678465723991394
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 819
#                 y: 924
#               }
#               vertices {
#                 x: 854
#                 y: 924
#               }
#               vertices {
#                 x: 854
#                 y: 973
#               }
#               vertices {
#                 x: 819
#                 y: 973
#               }
#             }
#             text: "a"
#             confidence: 0.9787442684173584
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 851
#                 y: 924
#               }
#               vertices {
#                 x: 880
#                 y: 924
#               }
#               vertices {
#                 x: 880
#                 y: 973
#               }
#               vertices {
#                 x: 851
#                 y: 973
#               }
#             }
#             text: "r"
#             confidence: 0.9678663015365601
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 871
#                 y: 924
#               }
#               vertices {
#                 x: 903
#                 y: 924
#               }
#               vertices {
#                 x: 903
#                 y: 973
#               }
#               vertices {
#                 x: 871
#                 y: 973
#               }
#             }
#             text: "d"
#             confidence: 0.9629518985748291
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 899
#                 y: 924
#               }
#               vertices {
#                 x: 923
#                 y: 924
#               }
#               vertices {
#                 x: 923
#                 y: 973
#               }
#               vertices {
#                 x: 899
#                 y: 973
#               }
#             }
#             text: "s"
#             confidence: 0.9600974917411804
#           }
#           confidence: 0.9679595232009888
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 942
#               y: 924
#             }
#             vertices {
#               x: 1031
#               y: 924
#             }
#             vertices {
#               x: 1031
#               y: 973
#             }
#             vertices {
#               x: 942
#               y: 973
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 942
#                 y: 924
#               }
#               vertices {
#                 x: 980
#                 y: 924
#               }
#               vertices {
#                 x: 980
#                 y: 973
#               }
#               vertices {
#                 x: 942
#                 y: 973
#               }
#             }
#             text: "J"
#             confidence: 0.9317964911460876
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 970
#                 y: 924
#               }
#               vertices {
#                 x: 998
#                 y: 924
#               }
#               vertices {
#                 x: 998
#                 y: 973
#               }
#               vertices {
#                 x: 970
#                 y: 973
#               }
#             }
#             text: "o"
#             confidence: 0.9541005492210388
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 993
#                 y: 924
#               }
#               vertices {
#                 x: 1031
#                 y: 924
#               }
#               vertices {
#                 x: 1031
#                 y: 973
#               }
#               vertices {
#                 x: 993
#                 y: 973
#               }
#             }
#             text: "y"
#             confidence: 0.8812747597694397
#           }
#           confidence: 0.9223905801773071
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1.0
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1026
#               y: 924
#             }
#             vertices {
#               x: 1052
#               y: 924
#             }
#             vertices {
#               x: 1052
#               y: 973
#             }
#             vertices {
#               x: 1026
#               y: 973
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1026
#                 y: 924
#               }
#               vertices {
#                 x: 1052
#                 y: 924
#               }
#               vertices {
#                 x: 1052
#                 y: 973
#               }
#               vertices {
#                 x: 1026
#                 y: 973
#               }
#             }
#             text: "."
#             confidence: 0.8732468485832214
#           }
#           confidence: 0.8732468485832214
#         }
#         confidence: 0.9028476476669312
#       }
#       block_type: TEXT
#       confidence: 0.9028476476669312
#     }
#     confidence: 0.8908588886260986
#   }
#   text: "#1\nWhat is Mindfulness\n#2\nHabits of Mind\n#3\nUnderstanding our Thoughts & Emotions\n#4\nCultivating Love - Kindness\n#5\nWillingness to be with things as they are\n#6\nIndining mind towards Joy."
# }

# %% [markdown]
# Todo
#
# > How about detecting labels?

# %%
# see https://cloud.google.com/vision/docs/labels

def detect_labels(path):

# %%
detect_labels('nyp_cafe.jpg')

# %% [markdown]
# *Sample output:*
#
# <pre>
# Labels:
# Leisure
# Customer
# T-shirt
# Eyewear
# Event
# Fun
# Water bottle
# Belt
# Job
# Room
# </pre>
